# %%
import pandas as pd
import os
import subprocess

pd.set_option('display.width', None)  # Adjust display width
pd.set_option('display.max_colwidth', None)  # Adjust column width

def read_csv_file(file_path):
    """
    Read a CSV file from the specified file path and return the DataFrame.
    """
    return pd.read_csv(file_path)

def merge_library_pool_components_dfs(df1, df2):
    """
    Merge two DataFrames from library pool components and return the merged result 
    with updated 'library_pool_local_name' and the concatenated name.
    """
    merged_df = pd.concat([df1, df2], ignore_index=True)
    unique_names_1 = df1['library_pool_local_name'].unique()
    unique_names_2 = df2['library_pool_local_name'].unique()
    concatenated_name = '_'.join(sorted([unique_names_1[0], unique_names_2[0]]))
    merged_df['library_pool_local_name'] = concatenated_name
    return merged_df, concatenated_name

def write_csv_file(data, output_file_path):
    """
    Write DataFrame to a specified CSV file path.
    """
    os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
    data.to_csv(output_file_path, index=False)
    print(f"Data written to {output_file_path}")  # Controlled print statement

def check_and_convert_date_format(data, column_name, original_format, target_format):
    """
    Convert date format of a column within a DataFrame.
    """
    data[column_name] = pd.to_datetime(data[column_name], format=original_format, errors='coerce').dt.strftime(target_format)

def combine_pools(input_directory1, input_directory2, new_barcode):
    """
    Combine library pool data from two directories, updating and saving the results to a new directory.
    """
    component_path1 = os.path.join(input_directory1, 'library_pool_component.csv')
    component_path2 = os.path.join(input_directory2, 'library_pool_component.csv')
    
    df1 = read_csv_file(component_path1)
    df2 = read_csv_file(component_path2)
    merged_df, concatenated_name = merge_library_pool_components_dfs(df1, df2)

    output_directory = os.path.join(os.path.dirname(input_directory1), concatenated_name)
    output_component_path = os.path.join(output_directory, 'library_pool_component.csv')
    
    write_csv_file(merged_df, output_component_path)
    # The print_file_contents function calls are removed to prevent direct output

    # Similar steps for the main library pool CSV processing should be included here if necessary

    return output_directory

def process_library_pool(input_directory, output_directory, concatenated_name, new_barcode):
    """
    Process and update the library pool CSV.
    """
    library_pool_path = os.path.join(input_directory, 'library_pool.csv')
    data = read_csv_file(library_pool_path)
    
    check_and_convert_date_format(data, 'library_pool_preparation_date', '%y/%m/%d', '%m/%d/%Y')
    data['library_pool_local_name'] = concatenated_name
    data['library_pool_local_tube_id'] = concatenated_name
    data['library_pool_tube_barcode'] = new_barcode
    
    return data

def concatenate_other_tables(input_directory1, input_directory2, output_directory):
    """
    Concatenates 'barcoded_cell_sample_component.csv', 'barcoded_cell_sample.csv', and 'library.csv'
    from two directories into separate combined DataFrames and saves them to the given output directory.
    Then prints the contents of these files.
    """
    # Define the paths for all three file types in both directories
    component_path1 = os.path.join(input_directory1, 'barcoded_cell_sample_component.csv')
    component_path2 = os.path.join(input_directory2, 'barcoded_cell_sample_component.csv')
    sample_path1 = os.path.join(input_directory1, 'barcoded_cell_sample.csv')
    sample_path2 = os.path.join(input_directory2, 'barcoded_cell_sample.csv')
    library_path1 = os.path.join(input_directory1, 'library.csv')
    library_path2 = os.path.join(input_directory2, 'library.csv')
    
    # Read and concatenate 'barcoded_cell_sample_component.csv'
    df_component1 = pd.read_csv(component_path1)
    df_component2 = pd.read_csv(component_path2)
    concatenated_components = pd.concat([df_component1, df_component2], ignore_index=True)
    
    # Read and concatenate 'barcoded_cell_sample.csv'
    df_sample1 = pd.read_csv(sample_path1)
    df_sample2 = pd.read_csv(sample_path2)
    concatenated_samples = pd.concat([df_sample1, df_sample2], ignore_index=True)

    # Read and concatenate 'library.csv'
    df_library1 = pd.read_csv(library_path1)
    df_library2 = pd.read_csv(library_path2)
    concatenated_libraries = pd.concat([df_library1, df_library2], ignore_index=True)
    
    # Save concatenated DataFrames to new CSV files
    output_component_path = os.path.join(output_directory, 'barcoded_cell_sample_component.csv')
    output_sample_path = os.path.join(output_directory, 'barcoded_cell_sample.csv')
    output_library_path = os.path.join(output_directory, 'library.csv')
    
    concatenated_components.to_csv(output_component_path, index=False)
    concatenated_samples.to_csv(output_sample_path, index=False)
    concatenated_libraries.to_csv(output_library_path, index=False)
    
    # Optionally return the DataFrames
    return concatenated_components, concatenated_samples, concatenated_libraries

input_path1 = '/gale/netapp/seq11/illumina_runs/seq_lib_portal/SALK062'
input_path2 = '/gale/netapp/seq11/illumina_runs/seq_lib_portal/SALK063'
barcode = 'SM-NQUJ9'

output_directory_path = combine_pools(input_path1, input_path2, barcode)
concatenate_other_tables(input_path1, input_path2, output_directory_path)
# Out:
# Data written to /gale/netapp/seq11/illumina_runs/seq_lib_portal/SALK062_SALK063/library_pool_component.csv
# (      barcoded_cell_sample_local_name barcoded_cell_sample_source_type  \
#  0      UWA7648_CX2324_SubTH_1_P1-1-I3             enriched_cell_sample
#  1      UWA7648_CX2324_SubTH_1_P2-1-E5             enriched_cell_sample
#  2      UWA7648_CX2324_SubTH_1_P3-1-O5             enriched_cell_sample
#  3      UWA7648_CX2324_SubTH_1_P4-1-C7             enriched_cell_sample
#  4      UWA7648_CX2324_SubTH_1_P5-1-K9             enriched_cell_sample
#  5      UWA7648_CX2324_SubTH_1_P6-1-M9             enriched_cell_sample
#  6     UWA7648_CX2324_SubTH_1_P7-1-A11             enriched_cell_sample
#  7     UWA7648_CX2324_SubTH_1_P8-1-I15             enriched_cell_sample
#  8     UWA7648_CX2324_SubTH_1_P9-1-M14             enriched_cell_sample
#  9    UWA7648_CX2324_SubTH_1_P10-1-K18             enriched_cell_sample
#  10   UWA7648_CX2324_SubTH_1_P11-1-K20             enriched_cell_sample
#  11       UWA7648_BS02_MGM3_1_P1-1-E22             enriched_cell_sample
#  12       UWA7648_BS02_MGM3_1_P2-1-I24             enriched_cell_sample
#  13        UWA7648_BS02_MGM3_1_P3-1-J3             enriched_cell_sample
#  14        UWA7648_BS02_MGM3_1_P4-1-L3             enriched_cell_sample
#  15        UWA7648_BS02_MGM3_1_P5-1-J7             enriched_cell_sample
#  16   UWA7648_BS030405_PnTg_1_P1-1-K15             enriched_cell_sample
#  17   UWA7648_BS030405_PnTg_1_P2-1-M17             enriched_cell_sample
#  18   UWA7648_BS030405_PnTg_1_P3-1-C21             enriched_cell_sample
#  19   UWA7648_BS030405_PnTg_1_P4-1-O21             enriched_cell_sample
#  20   UWA7648_BS030405_PnTg_1_P5-1-C23             enriched_cell_sample
#  21    UWA7648_BS030405_PnTg_1_P6-1-I2             enriched_cell_sample
#  22   UWA7648_BS030405_PnTg_1_P7-1-C10             enriched_cell_sample
#  23   UWA7648_BS030405_PnTg_1_P8-1-G10             enriched_cell_sample
#  24   UWA7648_BS030405_PnTg_1_P9-1-B11             enriched_cell_sample
#  25  UWA7648_BS030405_PnTg_1_P10-1-J11             enriched_cell_sample
#  26   UWA7648_BS030405_PnTg_1_P11-1-J2             enriched_cell_sample
#  27   UWA7648_BS030405_PnTg_1_P12-1-B6             enriched_cell_sample
#  28   UWA7648_BS030405_PnTg_1_P13-1-D6             enriched_cell_sample
#  29   UWA7648_BS030405_PnTg_1_P14-1-F6             enriched_cell_sample
#  30   UWA7648_BS030405_PnTg_1_P15-1-H6             enriched_cell_sample
#  31   UWA7648_BS030405_PnTg_1_P16-1-D8             enriched_cell_sample
#
#      dissociated_cell_sample_local_name       enriched_cell_sample_local_name
#  0                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  1                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  2                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  3                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  4                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  5                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  6                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  7                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  8                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  9                                  NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  10                                 NaN      UWA.7648.CX23,CX24.SubTH.E.01.90
#  11                                 NaN            UWA.7648.BS02.MGM3.E.01.90
#  12                                 NaN            UWA.7648.BS02.MGM3.E.01.90
#  13                                 NaN            UWA.7648.BS02.MGM3.E.01.90
#  14                                 NaN            UWA.7648.BS02.MGM3.E.01.90
#  15                                 NaN            UWA.7648.BS02.MGM3.E.01.90
#  16                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  17                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  18                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  19                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  20                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  21                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  22                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  23                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  24                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  25                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  26                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  27                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  28                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  29                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  30                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90
#  31                                 NaN  UWA.7648.BS03,BS04,BS05.PnTg.E.01.90  ,
#        barcoded_cell_sample_local_name barcoded_cell_sample_source_type  \
#  0      UWA7648_CX2324_SubTH_1_P1-1-I3             enriched_cell_sample
#  1      UWA7648_CX2324_SubTH_1_P2-1-E5             enriched_cell_sample
#  2      UWA7648_CX2324_SubTH_1_P3-1-O5             enriched_cell_sample
#  3      UWA7648_CX2324_SubTH_1_P4-1-C7             enriched_cell_sample
#  4      UWA7648_CX2324_SubTH_1_P5-1-K9             enriched_cell_sample
#  5      UWA7648_CX2324_SubTH_1_P6-1-M9             enriched_cell_sample
#  6     UWA7648_CX2324_SubTH_1_P7-1-A11             enriched_cell_sample
#  7     UWA7648_CX2324_SubTH_1_P8-1-I15             enriched_cell_sample
#  8     UWA7648_CX2324_SubTH_1_P9-1-M14             enriched_cell_sample
#  9    UWA7648_CX2324_SubTH_1_P10-1-K18             enriched_cell_sample
#  10   UWA7648_CX2324_SubTH_1_P11-1-K20             enriched_cell_sample
#  11       UWA7648_BS02_MGM3_1_P1-1-E22             enriched_cell_sample
#  12       UWA7648_BS02_MGM3_1_P2-1-I24             enriched_cell_sample
#  13        UWA7648_BS02_MGM3_1_P3-1-J3             enriched_cell_sample
#  14        UWA7648_BS02_MGM3_1_P4-1-L3             enriched_cell_sample
#  15        UWA7648_BS02_MGM3_1_P5-1-J7             enriched_cell_sample
#  16   UWA7648_BS030405_PnTg_1_P1-1-K15             enriched_cell_sample
#  17   UWA7648_BS030405_PnTg_1_P2-1-M17             enriched_cell_sample
#  18   UWA7648_BS030405_PnTg_1_P3-1-C21             enriched_cell_sample
#  19   UWA7648_BS030405_PnTg_1_P4-1-O21             enriched_cell_sample
#  20   UWA7648_BS030405_PnTg_1_P5-1-C23             enriched_cell_sample
#  21    UWA7648_BS030405_PnTg_1_P6-1-I2             enriched_cell_sample
#  22   UWA7648_BS030405_PnTg_1_P7-1-C10             enriched_cell_sample
#  23   UWA7648_BS030405_PnTg_1_P8-1-G10             enriched_cell_sample
#  24   UWA7648_BS030405_PnTg_1_P9-1-B11             enriched_cell_sample
#  25  UWA7648_BS030405_PnTg_1_P10-1-J11             enriched_cell_sample
#  26   UWA7648_BS030405_PnTg_1_P11-1-J2             enriched_cell_sample
#  27   UWA7648_BS030405_PnTg_1_P12-1-B6             enriched_cell_sample
#  28   UWA7648_BS030405_PnTg_1_P13-1-D6             enriched_cell_sample
#  29   UWA7648_BS030405_PnTg_1_P14-1-F6             enriched_cell_sample
#  30   UWA7648_BS030405_PnTg_1_P15-1-H6             enriched_cell_sample
#  31   UWA7648_BS030405_PnTg_1_P16-1-D8             enriched_cell_sample
#
#      barcoded_cell_sample_number_of_expected_cells  \
#  0                                            6144
#  1                                            6144
#  2                                            6144
#  3                                            6144
#  4                                            6144
#  5                                            6144
#  6                                            6144
#  7                                            6144
#  8                                            6144
#  9                                            6144
#  10                                           6144
#  11                                           6144
#  12                                           6144
#  13                                           6144
#  14                                           6144
#  15                                           6144
#  16                                           6144
#  17                                           6144
#  18                                           6144
#  19                                           6144
#  20                                           6144
#  21                                           6144
#  22                                           6144
#  23                                           6144
#  24                                           6144
#  25                                           6144
#  26                                           6144
#  27                                           6144
#  28                                           6144
#  29                                           6144
#  30                                           6144
#  31                                           6144
#
#     barcoded_cell_sample_preparation_date project_identifier  \
#  0                             04/18/2024  UM1MH130994-Ecker
#  1                             04/18/2024  UM1MH130994-Ecker
#  2                             04/18/2024  UM1MH130994-Ecker
#  3                             04/18/2024  UM1MH130994-Ecker
#  4                             04/18/2024  UM1MH130994-Ecker
#  5                             04/18/2024  UM1MH130994-Ecker
#  6                             04/18/2024  UM1MH130994-Ecker
#  7                             04/18/2024  UM1MH130994-Ecker
#  8                             04/18/2024  UM1MH130994-Ecker
#  9                             04/18/2024  UM1MH130994-Ecker
#  10                            04/18/2024  UM1MH130994-Ecker
#  11                            04/18/2024  UM1MH130994-Ecker
#  12                            04/18/2024  UM1MH130994-Ecker
#  13                            04/18/2024  UM1MH130994-Ecker
#  14                            04/18/2024  UM1MH130994-Ecker
#  15                            04/18/2024  UM1MH130994-Ecker
#  16                            04/22/2024  UM1MH130994-Ecker
#  17                            04/22/2024  UM1MH130994-Ecker
#  18                            04/22/2024  UM1MH130994-Ecker
#  19                            04/22/2024  UM1MH130994-Ecker
#  20                            04/22/2024  UM1MH130994-Ecker
#  21                            04/22/2024  UM1MH130994-Ecker
#  22                            04/22/2024  UM1MH130994-Ecker
#  23                            04/22/2024  UM1MH130994-Ecker
#  24                            04/22/2024  UM1MH130994-Ecker
#  25                            04/22/2024  UM1MH130994-Ecker
#  26                            04/22/2024  UM1MH130994-Ecker
#  27                            04/22/2024  UM1MH130994-Ecker
#  28                            04/22/2024  UM1MH130994-Ecker
#  29                            04/22/2024  UM1MH130994-Ecker
#  30                            04/22/2024  UM1MH130994-Ecker
#  31                            04/22/2024  UM1MH130994-Ecker
#
#     barcoded_cell_sample_technique
#  0                       snm3C-seq
#  1                       snm3C-seq
#  2                       snm3C-seq
#  3                       snm3C-seq
#  4                       snm3C-seq
#  5                       snm3C-seq
#  6                       snm3C-seq
#  7                       snm3C-seq
#  8                       snm3C-seq
#  9                       snm3C-seq
#  10                      snm3C-seq
#  11                      snm3C-seq
#  12                      snm3C-seq
#  13                      snm3C-seq
#  14                      snm3C-seq
#  15                      snm3C-seq
#  16                      snm3C-seq
#  17                      snm3C-seq
#  18                      snm3C-seq
#  19                      snm3C-seq
#  20                      snm3C-seq
#  21                      snm3C-seq
#  22                      snm3C-seq
#  23                      snm3C-seq
#  24                      snm3C-seq
#  25                      snm3C-seq
#  26                      snm3C-seq
#  27                      snm3C-seq
#  28                      snm3C-seq
#  29                      snm3C-seq
#  30                      snm3C-seq
#  31                      snm3C-seq  ,
#                     library_local_name library_technique  library_r1_r2_index  \
#  0      UWA7648_CX2324_SubTH_1_P1-1-I3         snm3C-seq                  NaN
#  1      UWA7648_CX2324_SubTH_1_P2-1-E5         snm3C-seq                  NaN
#  2      UWA7648_CX2324_SubTH_1_P3-1-O5         snm3C-seq                  NaN
#  3      UWA7648_CX2324_SubTH_1_P4-1-C7         snm3C-seq                  NaN
#  4      UWA7648_CX2324_SubTH_1_P5-1-K9         snm3C-seq                  NaN
#  5      UWA7648_CX2324_SubTH_1_P6-1-M9         snm3C-seq                  NaN
#  6     UWA7648_CX2324_SubTH_1_P7-1-A11         snm3C-seq                  NaN
#  7     UWA7648_CX2324_SubTH_1_P8-1-I15         snm3C-seq                  NaN
#  8     UWA7648_CX2324_SubTH_1_P9-1-M14         snm3C-seq                  NaN
#  9    UWA7648_CX2324_SubTH_1_P10-1-K18         snm3C-seq                  NaN
#  10   UWA7648_CX2324_SubTH_1_P11-1-K20         snm3C-seq                  NaN
#  11       UWA7648_BS02_MGM3_1_P1-1-E22         snm3C-seq                  NaN
#  12       UWA7648_BS02_MGM3_1_P2-1-I24         snm3C-seq                  NaN
#  13        UWA7648_BS02_MGM3_1_P3-1-J3         snm3C-seq                  NaN
#  14        UWA7648_BS02_MGM3_1_P4-1-L3         snm3C-seq                  NaN
#  15        UWA7648_BS02_MGM3_1_P5-1-J7         snm3C-seq                  NaN
#  16   UWA7648_BS030405_PnTg_1_P1-1-K15         snm3C-seq                  NaN
#  17   UWA7648_BS030405_PnTg_1_P2-1-M17         snm3C-seq                  NaN
#  18   UWA7648_BS030405_PnTg_1_P3-1-C21         snm3C-seq                  NaN
#  19   UWA7648_BS030405_PnTg_1_P4-1-O21         snm3C-seq                  NaN
#  20   UWA7648_BS030405_PnTg_1_P5-1-C23         snm3C-seq                  NaN
#  21    UWA7648_BS030405_PnTg_1_P6-1-I2         snm3C-seq                  NaN
#  22   UWA7648_BS030405_PnTg_1_P7-1-C10         snm3C-seq                  NaN
#  23   UWA7648_BS030405_PnTg_1_P8-1-G10         snm3C-seq                  NaN
#  24   UWA7648_BS030405_PnTg_1_P9-1-B11         snm3C-seq                  NaN
#  25  UWA7648_BS030405_PnTg_1_P10-1-J11         snm3C-seq                  NaN
#  26   UWA7648_BS030405_PnTg_1_P11-1-J2         snm3C-seq                  NaN
#  27   UWA7648_BS030405_PnTg_1_P12-1-B6         snm3C-seq                  NaN
#  28   UWA7648_BS030405_PnTg_1_P13-1-D6         snm3C-seq                  NaN
#  29   UWA7648_BS030405_PnTg_1_P14-1-F6         snm3C-seq                  NaN
#  30   UWA7648_BS030405_PnTg_1_P15-1-H6         snm3C-seq                  NaN
#  31   UWA7648_BS030405_PnTg_1_P16-1-D8         snm3C-seq                  NaN
#
#     library_preparation_date  library_additional_commnents  \
#  0                04/18/2024                           NaN
#  1                04/18/2024                           NaN
#  2                04/18/2024                           NaN
#  3                04/18/2024                           NaN
#  4                04/18/2024                           NaN
#  5                04/18/2024                           NaN
#  6                04/18/2024                           NaN
#  7                04/18/2024                           NaN
#  8                04/18/2024                           NaN
#  9                04/18/2024                           NaN
#  10               04/18/2024                           NaN
#  11               04/18/2024                           NaN
#  12               04/18/2024                           NaN
#  13               04/18/2024                           NaN
#  14               04/18/2024                           NaN
#  15               04/18/2024                           NaN
#  16               04/22/2024                           NaN
#  17               04/22/2024                           NaN
#  18               04/22/2024                           NaN
#  19               04/22/2024                           NaN
#  20               04/22/2024                           NaN
#  21               04/22/2024                           NaN
#  22               04/22/2024                           NaN
#  23               04/22/2024                           NaN
#  24               04/22/2024                           NaN
#  25               04/22/2024                           NaN
#  26               04/22/2024                           NaN
#  27               04/22/2024                           NaN
#  28               04/22/2024                           NaN
#  29               04/22/2024                           NaN
#  30               04/22/2024                           NaN
#  31               04/22/2024                           NaN
#
#       library_source_type    barcoded_cell_sample_local_name  \
#  0   barcoded_cell_sample     UWA7648_CX2324_SubTH_1_P1-1-I3
#  1   barcoded_cell_sample     UWA7648_CX2324_SubTH_1_P2-1-E5
#  2   barcoded_cell_sample     UWA7648_CX2324_SubTH_1_P3-1-O5
#  3   barcoded_cell_sample     UWA7648_CX2324_SubTH_1_P4-1-C7
#  4   barcoded_cell_sample     UWA7648_CX2324_SubTH_1_P5-1-K9
#  5   barcoded_cell_sample     UWA7648_CX2324_SubTH_1_P6-1-M9
#  6   barcoded_cell_sample    UWA7648_CX2324_SubTH_1_P7-1-A11
#  7   barcoded_cell_sample    UWA7648_CX2324_SubTH_1_P8-1-I15
#  8   barcoded_cell_sample    UWA7648_CX2324_SubTH_1_P9-1-M14
#  9   barcoded_cell_sample   UWA7648_CX2324_SubTH_1_P10-1-K18
#  10  barcoded_cell_sample   UWA7648_CX2324_SubTH_1_P11-1-K20
#  11  barcoded_cell_sample       UWA7648_BS02_MGM3_1_P1-1-E22
#  12  barcoded_cell_sample       UWA7648_BS02_MGM3_1_P2-1-I24
#  13  barcoded_cell_sample        UWA7648_BS02_MGM3_1_P3-1-J3
#  14  barcoded_cell_sample        UWA7648_BS02_MGM3_1_P4-1-L3
#  15  barcoded_cell_sample        UWA7648_BS02_MGM3_1_P5-1-J7
#  16  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P1-1-K15
#  17  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P2-1-M17
#  18  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P3-1-C21
#  19  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P4-1-O21
#  20  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P5-1-C23
#  21  barcoded_cell_sample    UWA7648_BS030405_PnTg_1_P6-1-I2
#  22  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P7-1-C10
#  23  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P8-1-G10
#  24  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P9-1-B11
#  25  barcoded_cell_sample  UWA7648_BS030405_PnTg_1_P10-1-J11
#  26  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P11-1-J2
#  27  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P12-1-B6
#  28  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P13-1-D6
#  29  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P14-1-F6
#  30  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P15-1-H6
#  31  barcoded_cell_sample   UWA7648_BS030405_PnTg_1_P16-1-D8
#
#      amplified_cdna_local_name project_identifier
#  0                         NaN  UM1MH130994-Ecker
#  1                         NaN  UM1MH130994-Ecker
#  2                         NaN  UM1MH130994-Ecker
#  3                         NaN  UM1MH130994-Ecker
#  4                         NaN  UM1MH130994-Ecker
#  5                         NaN  UM1MH130994-Ecker
#  6                         NaN  UM1MH130994-Ecker
#  7                         NaN  UM1MH130994-Ecker
#  8                         NaN  UM1MH130994-Ecker
#  9                         NaN  UM1MH130994-Ecker
#  10                        NaN  UM1MH130994-Ecker
#  11                        NaN  UM1MH130994-Ecker
#  12                        NaN  UM1MH130994-Ecker
#  13                        NaN  UM1MH130994-Ecker
#  14                        NaN  UM1MH130994-Ecker
#  15                        NaN  UM1MH130994-Ecker
#  16                        NaN  UM1MH130994-Ecker
#  17                        NaN  UM1MH130994-Ecker
#  18                        NaN  UM1MH130994-Ecker
#  19                        NaN  UM1MH130994-Ecker
#  20                        NaN  UM1MH130994-Ecker
#  21                        NaN  UM1MH130994-Ecker
#  22                        NaN  UM1MH130994-Ecker
#  23                        NaN  UM1MH130994-Ecker
#  24                        NaN  UM1MH130994-Ecker
#  25                        NaN  UM1MH130994-Ecker
#  26                        NaN  UM1MH130994-Ecker
#  27                        NaN  UM1MH130994-Ecker
#  28                        NaN  UM1MH130994-Ecker
#  29                        NaN  UM1MH130994-Ecker
#  30                        NaN  UM1MH130994-Ecker
#  31                        NaN  UM1MH130994-Ecker  )

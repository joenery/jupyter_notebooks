# %%
import gale_archives as gale
import pandas as pd
pd.set_option('display.max_colwidth', None)  # For pandas versions older than 1.0, use -1 instead of None
db_path = 'archives.db'
archive_type = 'aws'
archive_status = 'complete'
path_pattern = '%CX17%'
gale.fetch_filtered_paths_and_archives(db_path, path_pattern)
# Out:
#                                                                                                                                        path  \
# 0      /ceph/cephatlas/merscope_data/processed/202402161351_UWA-7648-CX17-CaH_VMSC12802/202402161351_UWA-7648-CX17-CaH_VMSC12802.raw.tar.gz
# 1      /ceph/cephatlas/merscope_data/processed/202402161351_UWA-7648-CX17-CaH_VMSC12802/202402161351_UWA-7648-CX17-CaH_VMSC12802.out.tar.gz
# 2  /ceph/cephatlas/merscope_data/processed/202402021109_uwa-7648-cx17-cah-5_VMSC12802/202402021109_uwa-7648-cx17-cah-5_VMSC12802.raw.tar.gz
# 3  /ceph/cephatlas/merscope_data/processed/202402021109_uwa-7648-cx17-cah-5_VMSC12802/202402021109_uwa-7648-cx17-cah-5_VMSC12802.out.tar.gz
# 4      /ceph/cephatlas/merscope_data/processed/202402161351_UWA-7648-CX17-CaH_VMSC12802/202402161351_UWA-7648-CX17-CaH_VMSC12802.raw.tar.gz
# 5      /ceph/cephatlas/merscope_data/processed/202402161351_UWA-7648-CX17-CaH_VMSC12802/202402161351_UWA-7648-CX17-CaH_VMSC12802.out.tar.gz
# 6  /ceph/cephatlas/merscope_data/processed/202402021109_uwa-7648-cx17-cah-5_VMSC12802/202402021109_uwa-7648-cx17-cah-5_VMSC12802.raw.tar.gz
# 7  /ceph/cephatlas/merscope_data/processed/202402021109_uwa-7648-cx17-cah-5_VMSC12802/202402021109_uwa-7648-cx17-cah-5_VMSC12802.out.tar.gz
#
#   path_type           created_at          modified_at  is_removed  \
# 0      file  2024-02-28 05:50:02  2024-02-28 05:50:02           0
# 1      file  2024-02-28 02:52:38  2024-02-28 02:52:38           0
# 2      file  2024-02-09 21:01:02  2024-02-09 21:01:02           0
# 3      file  2024-02-09 17:18:33  2024-02-09 17:18:33           0
# 4      file  2024-02-28 05:50:02  2024-02-28 05:50:02           0
# 5      file  2024-02-28 02:52:38  2024-02-28 02:52:38           0
# 6      file  2024-02-09 21:01:02  2024-02-09 21:01:02           0
# 7      file  2024-02-09 17:18:33  2024-02-09 17:18:33           0
#
#   archive_type archive_status         last_updated
# 0          aws       complete  2024-04-10 10:58:17
# 1          aws       complete  2024-04-10 10:58:17
# 2          aws       complete  2024-04-10 10:58:17
# 3          aws       complete  2024-04-10 10:58:17
# 4         dsmc       complete  2024-04-10 11:10:55
# 5         dsmc       complete  2024-04-10 11:10:55
# 6         dsmc       complete  2024-04-10 11:10:55
# 7         dsmc       complete  2024-04-10 11:10:55

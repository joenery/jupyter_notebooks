# %%
import gale_archives as gale

# %%
db_path = 'archives.db'
directory_path = '/gale/raidix/rdx-2/illumina_runs/'
archive_type = 'aws'  # or 'dsmc'

# %%
gale.update_archive_details_in_db(db_path, directory_path, archive_type)
# Out:
# Processing: /gale/raidix/rdx-2/illumina_runs/220401_A00280_0511_AH2KFGDRX2_220404130030850325710, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# Processing: /gale/raidix/rdx-2/illumina_runs/221118_A00280_0614_BH3VWFDRX2_221121092921871194333, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# Processing: /gale/raidix/rdx-2/illumina_runs/221118_A00280_0614_BH3VWFDRX2_221121151115444106644, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# Processing: /gale/raidix/rdx-2/illumina_runs/221128_A00280_0617_BHLM75DSX5_221130132551330402826, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# ...

# %%
table_name = 'Archives'
df = gale.get_db_table(db_path, table_name)
df
# Out:
#     archive_id  path_id archive_type archive_status         last_updated  \
# 0            1        1          aws        pending  2024-04-09 12:50:05
# 1            2        2          aws        pending  2024-04-09 12:50:05
# 2            3        3          aws        pending  2024-04-09 12:50:05
# 3            4        4          aws        pending  2024-04-09 12:50:05
# 4            5        5          aws        pending  2024-04-09 12:50:05
# 5            6        6          aws        pending  2024-04-09 12:50:05
# 6            7        7          aws        pending  2024-04-09 12:50:05
# 7            8        8          aws        pending  2024-04-09 12:50:05
# 8            9        9          aws        pending  2024-04-09 12:50:05
# 9           10       10          aws        pending  2024-04-09 12:50:05
# 10          11       11          aws        pending  2024-04-09 12:50:05
# 11          12       12          aws       complete  2024-04-09 12:50:05
# ...

# %%
db_path = 'archives.db'
directory_path = '/gale/raidix/rdx-2/illumina_runs/'
archive_type = 'dsmc'  # or 'aws'
gale.update_archive_details_in_db(db_path, directory_path, archive_type)
# Out:
# Processing: /gale/raidix/rdx-2/illumina_runs/220401_A00280_0511_AH2KFGDRX2_220404130030850325710, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# Processing: /gale/raidix/rdx-2/illumina_runs/221118_A00280_0614_BH3VWFDRX2_221121092921871194333, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# Processing: /gale/raidix/rdx-2/illumina_runs/221118_A00280_0614_BH3VWFDRX2_221121151115444106644, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# Processing: /gale/raidix/rdx-2/illumina_runs/221128_A00280_0617_BHLM75DSX5_221130132551330402826, Type: directory, Archive Status: complete
# Inserted/Updated in Paths table successfully.
# Inserted/Updated in Archives table successfully.
# ...

# %%
table_name = 'Archives'
df = gale.get_db_table(db_path, table_name)
df
# Out:
#     archive_id  path_id archive_type archive_status         last_updated  \
# 0            1        1          aws        pending  2024-04-09 12:50:05
# 1            2        2          aws        pending  2024-04-09 12:50:05
# 2            3        3          aws        pending  2024-04-09 12:50:05
# 3            4        4          aws        pending  2024-04-09 12:50:05
# 4            5        5          aws        pending  2024-04-09 12:50:05
# ..         ...      ...          ...            ...                  ...
# 81         146      119         dsmc       complete  2024-04-09 13:56:19
# 82         147      120         dsmc       complete  2024-04-09 13:56:19
# 83         148      121         dsmc       complete  2024-04-09 13:56:19
# 84         149      122         dsmc       complete  2024-04-09 13:56:19
# 85         150      123         dsmc       complete  2024-04-09 13:56:19
#
#    additional_info
# 0             None
# 1             None
# 2             None
# ...

# %%
import gale_archives as gale
import pandas as pd
pd.set_option('display.max_colwidth', None)  # For pandas versions older than 1.0, use -1 instead of None
pd.set_option('display.width', 1000)  # Adjust based on your display area
db_path = 'archives.db'
gale.load_paths_details(db_path)
# Out:
#                                                                                                                                            path  path_type     age archive_type archive_status  is_removed
# 0                                                              /gale/raidix/rdx-1/illumina_runs/190227_M00412_0183_000000000-G3KKK_190228120440  directory  1868.0          aws        pending           0
# 1                                                              /gale/raidix/rdx-1/illumina_runs/190228_M00412_0184_000000000-G3KK2_190301115126  directory  1867.0          aws        pending           0
# 2                                                              /gale/raidix/rdx-1/illumina_runs/190308_M00412_0187_000000000-G3FND_190309133059  directory  1859.0          aws        pending           0
# 3                                                              /gale/raidix/rdx-1/illumina_runs/190308_M00412_0187_000000000-G3FND_190310212820  directory  1858.0          aws        pending           0
# 4                                                              /gale/raidix/rdx-1/illumina_runs/190206_M00412_0175_000000000-G3F4R_190211140350  directory  1885.0          aws        pending           0
# ..                                                                                                                                          ...        ...     ...          ...            ...         ...
# 181    /ceph/cephatlas/merscope_data/processed/202402021109_uwa-7648-cx17-cah-5_VMSC12802/202402021109_uwa-7648-cx17-cah-5_VMSC12802.out.tar.gz       file    61.0         dsmc       complete           0
# 182        /ceph/cephatlas/merscope_data/processed/202402161059_UWA-7648-CX20-CaB_VMSC01101/202402161059_UWA-7648-CX20-CaB_VMSC01101.raw.tar.gz       file    44.0         dsmc       complete           0
# 183        /ceph/cephatlas/merscope_data/processed/202402161059_UWA-7648-CX20-CaB_VMSC01101/202402161059_UWA-7648-CX20-CaB_VMSC01101.out.tar.gz       file    44.0         dsmc       complete           0
# 184  /ceph/cephatlas/merscope_data/processed/202402231147_UWA-7648-CX23-THM-01_VMSC12802/202402231147_UWA-7648-CX23-THM-01_VMSC12802.raw.tar.gz       file    43.0         dsmc       complete           0
# 185  /ceph/cephatlas/merscope_data/processed/202402231147_UWA-7648-CX23-THM-01_VMSC12802/202402231147_UWA-7648-CX23-THM-01_VMSC12802.out.tar.gz       file    43.0         dsmc       complete           0
#
# [186 rows x 6 columns]

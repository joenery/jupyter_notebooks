# %%
from broad_qc import read_dataframes, calculate_metrics, format_metrics, plot_reads_vs_sampleID_reversed

# %%
metrics_path = '/gale/netapp/seq11/illumina_runs/qc_metrics/'
file = 'LP-IIRITQ996614_Broad_QC__SALK005__22H7TLLT3.csv'
file_path = f'{metrics_path}/{file}'

# %%
demux_stats, top_unknown_barcodes = read_dataframes(file_path)
metrics = calculate_metrics(demux_stats, top_unknown_barcodes)
formatted_metrics = format_metrics(metrics)

# %%
for key, value in formatted_metrics.items():
        print(f"{key}: {value}")
# Out:
# run_yield: 4,010,750,134,005 >= Q30 Bases
# run_yield_excluding_undetermined: 3,717,727,409,907 >= Q30 Bases
# total_reads: 13,045,575,023 Reads PF
# assumed_phiX_reads: 365,810,944 Reads PF
# percent_phix_assumed: 2.80%

# %%
plot_reads_vs_sampleID_reversed(demux_stats)

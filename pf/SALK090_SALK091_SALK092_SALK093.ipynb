# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240614_M00412_0825_000000000-GLG26'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240614_M00412_0825_000000000-GLG26_240614133937343712753 SALK090
#                           SampleID  # Reads
# 0    UCI4723_CX1314_A25_1_P1-1-K15    73372
# 1    UCI4723_CX1314_A25_1_P14-1-F6    68315
# 2    UCI4723_CX1314_A25_1_P4-1-O21    67309
# 3    UCI4723_CX1314_A25_1_P2-1-M17    66845
# 4    UCI4723_CX1314_A25_1_P3-1-C21    65578
# 5    UCI4723_CX1314_A25_1_P16-1-D8    64756
# 6    UCI4723_CX1314_A25_1_P7-1-C10    62906
# 7   UCI4723_CX1314_A25_1_P10-1-J11    62081
# 8     UCI4723_CX1314_A25_1_P6-1-I2    58650
# 9    UCI4723_CX1314_A25_1_P5-1-C23    57834
# 10   UCI4723_CX1314_A25_1_P9-1-B11    57043
# 11   UCI4723_CX1314_A25_1_P12-1-B6    55610
# 12   UCI4723_CX1314_A25_1_P11-1-J2    55499
# 13   UCI4723_CX1314_A25_1_P13-1-D6    55357
# 14   UCI4723_CX1314_A25_1_P15-1-H6    53694
# 15   UCI4723_CX1314_A25_1_P8-1-G10    50098
# 16                  Total Reads PF   974947
# /gale/netapp/seq2/illumina_runs/240614_M00412_0825_000000000-GLG26_240614134047876400301 SALK091
#                           SampleID  # Reads
# 0   UCI4723_CX1516_ITC_1_P10-1-E21   125056
# 1    UCI4723_CX1516_ITC_1_P7-1-N22    92116
# 2     UCI4723_CX1516_ITC_1_P2-1-A6    86895
# 3    UCI4723_CX1516_ITC_1_P1-1-J12    80283
# 4   UCI4723_CX1516_ITC_1_P14-1-K11    77003
# 5     UCI4723_CX1516_ITC_1_P6-1-G5    76921
# 6     UCI4723_CX1516_ITC_1_P3-1-F8    70422
# 7    UCI4723_CX1516_ITC_1_P8-1-F12    68523
# 8   UCI4723_CX1516_ITC_1_P12-1-P11    64149
# 9    UCI4723_CX1516_ITC_1_P4-1-B23    62326
# 10  UCI4723_CX1516_ITC_1_P16-1-C18    61796
# 11   UCI4723_CX1516_ITC_1_P5-1-P21    60245
# 12  UCI4723_CX1516_ITC_1_P15-1-K21    53976
# 13  UCI4723_CX1516_ITC_1_P11-1-F21    52068
# 14   UCI4723_CX1516_ITC_1_P9-1-F19    46163
# 15   UCI4723_CX1516_ITC_1_P13-1-E8    43967
# 16                  Total Reads PF  1121909
# /gale/netapp/seq2/illumina_runs/240614_M00412_0825_000000000-GLG26_240614134136193820729 SALK092
#                           SampleID  # Reads
# 0   UCI4723_CX1516_CaB_1_P16-1-J18   137598
# 1    UCI4723_CX1516_CaB_1_P15-1-O4   128247
# 2    UCI4723_CX1516_CaB_1_P6-1-A22   112854
# 3     UCI4723_CX1516_CaB_1_P3-1-F3   108602
# 4    UCI4723_CX1516_CaB_1_P14-1-P6   108056
# 5    UCI4723_CX1516_CaB_1_P11-1-E9   107711
# 6    UCI4723_CX1516_CaB_1_P7-1-B19   106557
# 7   UCI4723_CX1516_CaB_1_P10-1-I17   105383
# 8    UCI4723_CX1516_CaB_1_P2-1-P13   103168
# 9   UCI4723_CX1516_CaB_1_P13-1-J24    97493
# 10    UCI4723_CX1516_CaB_1_P8-1-A7    95793
# 11   UCI4723_CX1516_CaB_1_P12-1-N8    92496
# 12    UCI4723_CX1516_CaB_1_P9-1-G9    91802
# 13    UCI4723_CX1516_CaB_1_P1-1-I5    91052
# 14   UCI4723_CX1516_CaB_1_P5-1-G17    88559
# 15    UCI4723_CX1516_CaB_1_P4-1-E6    88015
# 16                  Total Reads PF  1663386
# /gale/netapp/seq2/illumina_runs/240614_M00412_0825_000000000-GLG26_240614134234931760043 SALK093
#                            SampleID  # Reads
# 0   UCI4723_CX1718_HTH2_1_P12-1-E22    64465
# 1   UCI4723_CX1718_HTH2_1_P11-1-K20    61435
# 2    UCI4723_CX1718_HTH2_1_P15-1-L3    60014
# 3    UCI4723_CX1718_HTH2_1_P8-1-I15    58929
# 4    UCI4723_CX1718_HTH2_1_P9-1-M14    56223
# 5     UCI4723_CX1718_HTH2_1_P5-1-K9    54996
# 6    UCI4723_CX1718_HTH2_1_P14-1-J3    52980
# 7     UCI4723_CX1718_HTH2_1_P3-1-O5    52855
# 8     UCI4723_CX1718_HTH2_1_P4-1-C7    52834
# 9     UCI4723_CX1718_HTH2_1_P6-1-M9    52833
# 10    UCI4723_CX1718_HTH2_1_P1-1-I3    49996
# 11   UCI4723_CX1718_HTH2_1_P7-1-A11    49253
# 12  UCI4723_CX1718_HTH2_1_P10-1-K18    47025
# 13   UCI4723_CX1718_HTH2_1_P16-1-J7    46489
# 14    UCI4723_CX1718_HTH2_1_P2-1-E5    38761
# 15  UCI4723_CX1718_HTH2_1_P13-1-I24    32912
# 16                   Total Reads PF   832000
#       Pool  Total Reads
# 0  SALK090       974947
# 1  SALK091      1121909
# 2  SALK092      1663386
# 3  SALK093       832000

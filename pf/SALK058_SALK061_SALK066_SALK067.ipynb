# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240520_M00412_0816_000000000-DMY5N'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
#    print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
#    generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240520_M00412_0816_000000000-DMY5N'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240520_M00412_0816_000000000-DMY5N_240521081725611970715 SALK058
#                            SampleID  # Reads
# 0    UWA7648_BS0102_MGM1_1_P8-1-I15    12348
# 1     UWA7648_BS0102_MGM1_1_P5-1-K9    12225
# 2    UWA7648_BS0102_MGM1_2_P15-1-L3    11656
# 3     UWA7648_BS0102_MGM1_1_P1-1-I3    11609
# 4    UWA7648_BS0102_MGM1_1_P7-1-A11    11586
# 5    UWA7648_BS0102_MGM1_2_P16-1-J7    11354
# 6     UWA7648_BS0102_MGM1_1_P6-1-M9    11353
# 7     UWA7648_BS0102_MGM1_1_P2-1-E5    11173
# 8    UWA7648_BS0102_MGM1_2_P14-1-J3    11173
# 9   UWA7648_BS0102_MGM1_1_P12-1-E22    10963
# 10  UWA7648_BS0102_MGM1_1_P10-1-K18    10760
# 11  UWA7648_BS0102_MGM1_2_P13-1-I24    10698
# 12    UWA7648_BS0102_MGM1_1_P4-1-C7    10640
# 13    UWA7648_BS0102_MGM1_1_P3-1-O5    10283
# 14  UWA7648_BS0102_MGM1_1_P11-1-K20    10248
# 15   UWA7648_BS0102_MGM1_1_P9-1-M14    10135
# 16                   Total Reads PF   178204
# /gale/netapp/seq2/illumina_runs/240520_M00412_0816_000000000-DMY5N_240521081821049128096 SALK061
#                          SampleID  # Reads
# 0    UWA7648_BS01_MGM2_1_P6-1-A22    16063
# 1     UWA7648_BS01_MGM2_1_P3-1-F3    15912
# 2    UWA7648_BS01_MGM2_1_P2-1-P13    15879
# 3   UWA7648_BS01_MGM2_1_P16-1-J18    15789
# 4    UWA7648_BS01_MGM2_1_P15-1-O4    15603
# 5     UWA7648_BS01_MGM2_1_P1-1-I5    15199
# 6     UWA7648_BS01_MGM2_1_P4-1-E6    14948
# 7    UWA7648_BS01_MGM2_1_P5-1-G17    14634
# 8     UWA7648_BS01_MGM2_1_P9-1-G9    14092
# 9   UWA7648_BS01_MGM2_1_P13-1-J24    13845
# 10   UWA7648_BS01_MGM2_1_P11-1-E9    13795
# 11   UWA7648_BS01_MGM2_1_P7-1-B19    13757
# 12   UWA7648_BS01_MGM2_1_P12-1-N8    13401
# 13  UWA7648_BS01_MGM2_1_P10-1-I17    13193
# 14    UWA7648_BS01_MGM2_1_P8-1-A7    13002
# 15   UWA7648_BS01_MGM2_1_P14-1-P6    12356
# 16                 Total Reads PF   231468
# /gale/netapp/seq2/illumina_runs/240520_M00412_0816_000000000-DMY5N_240521081841822914267 SALK066
#                               SampleID  # Reads
# 0         UWA7648_BS02_MGM3_1_P6-1-K15    13186
# 1         UWA7648_BS02_MGM3_1_P7-1-M17    13012
# 2   UWA7648_CB67_Human_CBLP_1_P1-1-B11    12433
# 3    UWA7648_CB67_Human_CBLP_1_P5-1-D6    12229
# 4         UWA7648_BS02_MGM3_1_P8-1-C21    12223
# 5    UWA7648_CB67_Human_CBLP_1_P6-1-F6    11912
# 6   UWA7648_CB67_Human_CBLP_1_P2-1-J11    11863
# 7    UWA7648_CB67_Human_CBLP_1_P7-1-H6    11856
# 8        UWA7648_BS02_MGM3_1_P10-1-C23    11821
# 9         UWA7648_BS02_MGM3_1_P11-1-I2    11775
# 10       UWA7648_BS02_MGM3_1_P12-1-C10    11514
# 11        UWA7648_BS02_MGM3_1_P9-1-O21    11290
# 12   UWA7648_CB67_Human_CBLP_1_P3-1-J2    10591
# 13   UWA7648_CB67_Human_CBLP_1_P4-1-B6    10286
# 14   UWA7648_CB67_Human_CBLP_1_P8-1-D8     3862
# 15       UWA7648_BS02_MGM3_1_P13-1-G10     3372
# 16                      Total Reads PF   173225
# /gale/netapp/seq2/illumina_runs/240520_M00412_0816_000000000-DMY5N_240521081854790515478 SALK067
#                               SampleID  # Reads
# 0    UWA7648_CB60_Human_VeA_1_P7-1-N22    44379
# 1   UWA7648_CB60_Human_VeA_1_P10-1-E21    43374
# 2    UWA7648_CB60_Human_VeA_1_P13-1-E8    42579
# 3   UWA7648_CB60_Human_VeA_1_P12-1-P11    41715
# 4   UWA7648_CB60_Human_VeA_1_P14-1-K11    41365
# 5    UWA7648_CB60_Human_VeA_1_P1-1-J12    40245
# 6    UWA7648_CB60_Human_VeA_1_P4-1-B23    38823
# 7     UWA7648_CB60_Human_VeA_1_P3-1-F8    38379
# 8     UWA7648_CB60_Human_VeA_1_P2-1-A6    38328
# 9   UWA7648_CB60_Human_VeA_1_P15-1-K21    36297
# 10  UWA7648_CB60_Human_VeA_1_P16-1-C18    35227
# 11   UWA7648_CB60_Human_VeA_1_P5-1-P21    34210
# 12   UWA7648_CB60_Human_VeA_1_P8-1-F12    32368
# 13   UWA7648_CB60_Human_VeA_1_P9-1-F19    22757
# 14  UWA7648_CB60_Human_VeA_1_P11-1-F21    18029
# 15    UWA7648_CB60_Human_VeA_1_P6-1-G5    11852
# 16                      Total Reads PF   559927
#       Pool  Total Reads
# 0  SALK058       178204
# 1  SALK061       231468
# 2  SALK066       173225
# 3  SALK067       559927

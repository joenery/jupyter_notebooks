# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("240213_M00412_0784_000000000-GJMYP_240214133047961015331", "SALK034"),
    ("240213_M00412_0784_000000000-GJMYP_240214133051098552592", "SALK035"),
    ("240213_M00412_0784_000000000-GJMYP_240214133052464663036", "SALK036")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                          SampleID  # Reads
# 0      UWA7648_CX25_S1C_3_P5-1-K9   119950
# 1      UWA7648_CX25_S1C_3_P6-1-M9   109066
# 2      UWA7648_CX25_S1C_3_P3-1-O5   106571
# 3    UWA7648_CX25_S1C_3_P10-1-K18   106383
# 4      UWA7648_CX25_S1C_3_P4-1-C7   103832
# 5    UWA7648_CX2325_MTC_3_P6-1-J7   103037
# 6     UWA7648_CX25_S1C_3_P7-1-A11   102911
# 7      UWA7648_CX25_S1C_3_P1-1-I3   100788
# 8      UWA7648_CX25_S1C_3_P2-1-E5   100054
# 9   UWA7648_CX2325_MTC_3_P1-1-K20    99825
# 10   UWA7648_CX2325_MTC_3_P4-1-J3    98357
# 11   UWA7648_CX2325_MTC_3_P5-1-L3    97276
# 12    UWA7648_CX25_S1C_3_P9-1-M14    96134
# 13  UWA7648_CX2325_MTC_3_P2-1-E22    95473
# 14    UWA7648_CX25_S1C_3_P8-1-I15    94906
# 15  UWA7648_CX2325_MTC_3_P3-1-I24    87851
# 16                 Total Reads PF  1622414
#                             SampleID  # Reads
# 0       UWA7648_CX2426_MEC_3_P5-1-H6    83411
# 1       UWA7648_CX2426_MEC_3_P6-1-D8    73198
# 2       UWA7648_CX2426_MEC_3_P4-1-F6    70451
# 3       UWA7648_CX2426_MEC_3_P3-1-D6    69911
# 4   UWA7648_CX192021_CaB_2_P10-1-J11    63878
# 5    UWA7648_CX192021_CaB_2_P9-1-B11    62092
# 6       UWA7648_CX2426_MEC_3_P1-1-J2    62062
# 7     UWA7648_CX192021_CaB_2_P6-1-I2    60030
# 8    UWA7648_CX192021_CaB_2_P8-1-G10    59939
# 9    UWA7648_CX192021_CaB_2_P5-1-C23    58939
# 10   UWA7648_CX192021_CaB_2_P4-1-O21    58186
# 11   UWA7648_CX192021_CaB_2_P7-1-C10    56671
# 12      UWA7648_CX2426_MEC_3_P2-1-B6    56256
# 13   UWA7648_CX192021_CaB_2_P1-1-K15    54763
# 14   UWA7648_CX192021_CaB_2_P3-1-C21    54078
# 15   UWA7648_CX192021_CaB_2_P2-1-M17    52699
# 16                    Total Reads PF   996564
#                              SampleID  # Reads
# 0    UWA7648_CX282931_HIPc_1_P13-1-E8   153760
# 1    UWA7648_CX282931_HIPc_1_P9-1-F19   141233
# 2   UWA7648_CX282931_HIPc_1_P14-1-K11   129089
# 3   UWA7648_CX282931_HIPc_1_P11-1-F21   117010
# 4   UWA7648_CX282931_HIPc_1_P10-1-E21   115772
# 5    UWA7648_CX282931_HIPc_1_P7-1-N22   115035
# 6    UWA7648_CX282931_HIPc_1_P1-1-J12   112491
# 7     UWA7648_CX282931_HIPc_1_P2-1-A6   109522
# 8    UWA7648_CX282931_HIPc_1_P5-1-P21   109399
# 9     UWA7648_CX282931_HIPc_1_P3-1-F8   105420
# 10   UWA7648_CX282931_HIPc_1_P4-1-B23   104356
# 11    UWA7648_CX282931_HIPc_1_P6-1-G5   102677
# 12   UWA7648_CX282931_HIPc_1_P8-1-F12    93563
# 13  UWA7648_CX282931_HIPc_1_P15-1-K21    85826
# 14  UWA7648_CX282931_HIPc_1_P12-1-P11    65888
# 15  UWA7648_CX282931_HIPc_1_P16-1-C18       49
# 16                     Total Reads PF  1661090

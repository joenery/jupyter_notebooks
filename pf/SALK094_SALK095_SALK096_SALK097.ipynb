# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240621_M00412_0826_000000000-GLDH7'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240621_M00412_0826_000000000-GLDH7_240621142646438819648 SALK094
#                           SampleID  # Reads
# 0    UCI4723_CX1820_MTC_1_P5-1-C23   114699
# 1    UCI4723_CX1820_MTC_1_P9-1-B11   113442
# 2    UCI4723_CX1820_MTC_1_P8-1-G10   110109
# 3    UCI4723_CX1820_MTC_1_P3-1-C21   109858
# 4    UCI4723_CX1820_MTC_1_P7-1-C10   109257
# 5     UCI4723_CX1820_MTC_1_P6-1-I2   108384
# 6    UCI4723_CX1820_MTC_1_P4-1-O21   107121
# 7   UCI4723_CX1820_MTC_1_P10-1-J11   106068
# 8    UCI4723_CX1820_MTC_1_P16-1-D8    93528
# 9    UCI4723_CX1820_MTC_1_P13-1-D6    88963
# 10   UCI4723_CX1820_MTC_1_P14-1-F6    88401
# 11   UCI4723_CX1820_MTC_1_P15-1-H6    81038
# 12   UCI4723_CX1820_MTC_1_P11-1-J2    80303
# 13   UCI4723_CX1820_MTC_1_P12-1-B6    73778
# 14   UCI4723_CX1820_MTC_1_P2-1-M17    72939
# 15   UCI4723_CX1820_MTC_1_P1-1-K15     4725
# 16                  Total Reads PF  1462613
# /gale/netapp/seq2/illumina_runs/240621_M00412_0826_000000000-GLDH7_240621143306663249962 SALK095
#                          SampleID  # Reads
# 0    UCI4723_CX16_HTH1_1_P5-1-P21    90192
# 1    UCI4723_CX16_HTH1_1_P7-1-N22    84268
# 2   UCI4723_CX16_HTH1_1_P14-1-K11    75863
# 3   UCI4723_CX16_HTH1_1_P16-1-C18    72237
# 4    UCI4723_CX16_HTH1_1_P4-1-B23    71740
# 5    UCI4723_CX16_HTH1_1_P9-1-F19    71129
# 6    UCI4723_CX16_HTH1_1_P13-1-E8    70069
# 7   UCI4723_CX16_HTH1_1_P10-1-E21    69975
# 8    UCI4723_CX16_HTH1_1_P8-1-F12    69127
# 9    UCI4723_CX16_HTH1_1_P1-1-J12    68758
# 10    UCI4723_CX16_HTH1_1_P2-1-A6    68420
# 11  UCI4723_CX16_HTH1_1_P11-1-F21    67620
# 12    UCI4723_CX16_HTH1_1_P6-1-G5    66742
# 13    UCI4723_CX16_HTH1_1_P3-1-F8    59165
# 14  UCI4723_CX16_HTH1_1_P15-1-K21    55096
# 15  UCI4723_CX16_HTH1_1_P12-1-P11    52221
# 16                 Total Reads PF  1112622
# /gale/netapp/seq2/illumina_runs/240621_M00412_0826_000000000-GLDH7_240621151107059182296 SALK097
#                          SampleID  # Reads
# 0     UCI4723_CX2021_Ig_1_P5-1-K9    57621
# 1    UCI4723_CX2021_Ig_1_P7-1-A11    55099
# 2    UCI4723_CX2021_Ig_1_P16-1-J7    54926
# 3     UCI4723_CX2021_Ig_1_P3-1-O5    53802
# 4     UCI4723_CX2021_Ig_1_P1-1-I3    52994
# 5     UCI4723_CX2021_Ig_1_P4-1-C7    51623
# 6    UCI4723_CX2021_Ig_1_P9-1-M14    51595
# 7    UCI4723_CX2021_Ig_1_P15-1-L3    48953
# 8   UCI4723_CX2021_Ig_1_P13-1-I24    47988
# 9     UCI4723_CX2021_Ig_1_P2-1-E5    47951
# 10    UCI4723_CX2021_Ig_1_P6-1-M9    47512
# 11  UCI4723_CX2021_Ig_1_P11-1-K20    46803
# 12  UCI4723_CX2021_Ig_1_P10-1-K18    42039
# 13   UCI4723_CX2021_Ig_1_P14-1-J3    38501
# 14  UCI4723_CX2021_Ig_1_P12-1-E22    36331
# 15   UCI4723_CX2021_Ig_1_P8-1-I15     4449
# 16                 Total Reads PF   738187
# /gale/netapp/seq2/illumina_runs/240621_M00412_0826_000000000-GLDH7_240621150900098233871 SALK096
#                         SampleID  # Reads
# 0   UCI4723_CX21_M1C_1_P16-1-J18    79723
# 1    UCI4723_CX21_M1C_1_P7-1-B19    58240
# 2    UCI4723_CX21_M1C_1_P6-1-A22    58118
# 3     UCI4723_CX21_M1C_1_P1-1-I5    56041
# 4    UCI4723_CX21_M1C_1_P5-1-G17    54417
# 5     UCI4723_CX21_M1C_1_P8-1-A7    53405
# 6    UCI4723_CX21_M1C_1_P2-1-P13    52897
# 7     UCI4723_CX21_M1C_1_P4-1-E6    52213
# 8    UCI4723_CX21_M1C_1_P14-1-P6    51989
# 9     UCI4723_CX21_M1C_1_P3-1-F3    51967
# 10   UCI4723_CX21_M1C_1_P15-1-O4    51339
# 11  UCI4723_CX21_M1C_1_P13-1-J24    46874
# 12   UCI4723_CX21_M1C_1_P12-1-N8    43591
# 13   UCI4723_CX21_M1C_1_P11-1-E9    42116
# 14    UCI4723_CX21_M1C_1_P9-1-G9    36272
# 15  UCI4723_CX21_M1C_1_P10-1-I17    33683
# 16                Total Reads PF   822885
#       Pool  Total Reads
# 0  SALK094      1462613
# 1  SALK095      1112622
# 2  SALK097       738187
# 3  SALK096       822885

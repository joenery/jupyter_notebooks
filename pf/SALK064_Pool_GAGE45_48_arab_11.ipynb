# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("240503_M00412_0811_000000000-GK2MF_240503153735008439550", "SALK064"),
    ("240503_M00412_0811_000000000-GK2MF_240503154454862006441", "Pool_GAGE45_48"),
    ("240503_M00412_0811_000000000-GK2MF_240503154902332996394", "arab_11")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                          SampleID  # Reads
# 0    UWA7648_BS0304_PN_1_P6-1-A22   236020
# 1    UWA7648_BS0304_PN_1_P15-1-O4   233861
# 2     UWA7648_BS0304_PN_1_P3-1-F3   216193
# 3     UWA7648_BS0304_PN_1_P1-1-I5   212364
# 4    UWA7648_BS0304_PN_1_P5-1-G17   205603
# 5    UWA7648_BS0304_PN_1_P2-1-P13   202539
# 6   UWA7648_BS0304_PN_1_P10-1-I17   200195
# 7     UWA7648_BS0304_PN_1_P4-1-E6   199894
# 8   UWA7648_BS0304_PN_1_P16-1-J18   199139
# 9    UWA7648_BS0304_PN_1_P14-1-P6   197508
# 10   UWA7648_BS0304_PN_1_P7-1-B19   193267
# 11  UWA7648_BS0304_PN_1_P13-1-J24   191844
# 12    UWA7648_BS0304_PN_1_P8-1-A7   191781
# 13   UWA7648_BS0304_PN_1_P11-1-E9   190014
# 14   UWA7648_BS0304_PN_1_P12-1-N8   177428
# 15    UWA7648_BS0304_PN_1_P9-1-G9   173090
# 16                 Total Reads PF  3220740
#                                              SampleID  # Reads
# 0   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    69213
# 1   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    68736
# 2   240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    68454
# 3   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    68181
# 4   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    66436
# 5   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    61833
# 6   240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    60334
# 7   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    58249
# 8   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    57677
# 9   240307-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    55902
# 10  240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    55766
# 11  240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    53841
# 12  240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    53640
# 13  240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    53126
# 14  240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    48933
# 15  240425-iN-hs-snm3C_seq-NovaSeq-pe-150-BW-iN240...    23853
# 16                                     Total Reads PF   924174
#                                             SampleID  # Reads
# 0  240503--marchantia-snmCT_seq-NovaSeq-pe-150-JW...   272174
# 1  240503--at-snmCT_seq-NovaSeq-pe-150-JW-arabido...   165303
# 2                                     Total Reads PF   437477

# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("/gale/netapp/seq12/illumina_runs/240425_M00412_0805_000000000-DMY79_240430140323833502221/AD1", "AD1"),
    ("/gale/netapp/seq12/illumina_runs/240425_M00412_0805_000000000-DMY79_240430140323833502221/AD2", "AD2"),
    ("/gale/netapp/seq12/illumina_runs/240425_M00412_0805_000000000-DMY79_240430140323833502221", "AD1_AD2")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                                              SampleID  # Reads
# 0   240408_AD_HUMAN_adult_brain_2380_BA17__DNA_g_D...    69099
# 1   240408_AD_HUMAN_adult_brain_2274_BA17__DNA_g_D...    66431
# 2   240408_AD_HUMAN_adult_brain_2021_BA17__DNA_g_D...    64047
# 3   240408_AD_HUMAN_adult_brain_2339_BA09__DNA_g_D...    54157
# 4   240408_AD_HUMAN_adult_brain_2210_BA20__DNA_g_D...    52981
# 5   240408_AD_HUMAN_adult_brain_2327_BA09__DNA_g_D...    52752
# 6   240408_AD_HUMAN_adult_brain_2021_BA20__DNA_g_D...    52629
# 7   240408_AD_HUMAN_adult_brain_2068_BA09__DNA_g_D...    52455
# 8   240408_AD_HUMAN_adult_brain_2057_BA17__DNA_g_D...    51626
# 9   240408_AD_HUMAN_adult_brain_2097_BA17__DNA_g_D...    51132
# 10  240408_AD_HUMAN_adult_brain_2012_BA09__DNA_g_D...    49923
# 11  240408_AD_HUMAN_adult_brain_2026_BA17__DNA_g_D...    49168
# 12  240408_AD_HUMAN_adult_brain_2058_BA17__DNA_g_D...    48529
# 13                                     Total Reads PF   714929
# ...

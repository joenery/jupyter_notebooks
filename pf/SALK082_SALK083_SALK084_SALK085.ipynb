# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240605_M00412_0821_000000000-GLCPH'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240605_M00412_0821_000000000-GLCPH_240605151041437374833 SALK082
#                             SampleID  # Reads
# 0   UCI4723_CX1516_PalCx_1_P10-1-J11    55123
# 1    UCI4723_CX1516_PalCx_1_P1-1-K15    51935
# 2    UCI4723_CX1516_PalCx_1_P11-1-J2    49069
# 3    UCI4723_CX1516_PalCx_1_P3-1-C21    36913
# 4    UCI4723_CX1516_PalCx_1_P5-1-C23    31876
# 5    UCI4723_CX1516_PalCx_1_P13-1-D6    31688
# 6    UCI4723_CX1516_PalCx_1_P15-1-H6    28338
# 7    UCI4723_CX1516_PalCx_1_P8-1-G10    28326
# 8    UCI4723_CX1516_PalCx_1_P14-1-F6    27116
# 9    UCI4723_CX1516_PalCx_1_P7-1-C10    25650
# 10   UCI4723_CX1516_PalCx_1_P9-1-B11    25231
# 11   UCI4723_CX1516_PalCx_1_P12-1-B6    22732
# 12    UCI4723_CX1516_PalCx_1_P6-1-I2    22084
# 13   UCI4723_CX1516_PalCx_1_P2-1-M17    22055
# 14   UCI4723_CX1516_PalCx_1_P16-1-D8    21508
# 15   UCI4723_CX1516_PalCx_1_P4-1-O21    18974
# 16                    Total Reads PF   498618
# /gale/netapp/seq2/illumina_runs/240605_M00412_0821_000000000-GLCPH_240605151221029735265 SALK083
#                        SampleID  # Reads
# 0    UCI4723_CX15_FI_1_P9-1-F19   143522
# 1    UCI4723_CX15_FI_1_P5-1-P21   129521
# 2   UCI4723_CX15_FI_1_P14-1-K11   112916
# 3    UCI4723_CX15_FI_1_P7-1-N22   104254
# 4   UCI4723_CX15_FI_1_P10-1-E21   103141
# 5    UCI4723_CX15_FI_1_P13-1-E8   102452
# 6     UCI4723_CX15_FI_1_P2-1-A6   102335
# 7   UCI4723_CX15_FI_1_P11-1-F21   100582
# 8    UCI4723_CX15_FI_1_P4-1-B23   100015
# 9     UCI4723_CX15_FI_1_P6-1-G5    98924
# 10  UCI4723_CX15_FI_1_P12-1-P11    96155
# 11  UCI4723_CX15_FI_1_P16-1-C18    95326
# 12   UCI4723_CX15_FI_1_P1-1-J12    93340
# 13    UCI4723_CX15_FI_1_P3-1-F8    91268
# 14   UCI4723_CX15_FI_1_P8-1-F12    84907
# 15  UCI4723_CX15_FI_1_P15-1-K21    74829
# 16               Total Reads PF  1633487
# /gale/netapp/seq2/illumina_runs/240605_M00412_0821_000000000-GLCPH_240605151306176743136 SALK084
#                        SampleID  # Reads
# 0    UCI4723_CX13_A8_1_P7-1-B19    43104
# 1    UCI4723_CX13_A8_1_P6-1-A22    40487
# 2    UCI4723_CX13_A8_1_P15-1-O4    39728
# 3     UCI4723_CX13_A8_1_P8-1-A7    36611
# 4    UCI4723_CX13_A8_1_P11-1-E9    33534
# 5    UCI4723_CX13_A8_1_P14-1-P6    33447
# 6   UCI4723_CX13_A8_1_P13-1-J24    32005
# 7     UCI4723_CX13_A8_1_P3-1-F3    31395
# 8   UCI4723_CX13_A8_1_P16-1-J18    28836
# 9    UCI4723_CX13_A8_1_P5-1-G17    28780
# 10  UCI4723_CX13_A8_1_P10-1-I17    28762
# 11   UCI4723_CX13_A8_1_P12-1-N8    28285
# 12   UCI4723_CX13_A8_1_P2-1-P13    25851
# 13    UCI4723_CX13_A8_1_P9-1-G9    25763
# 14    UCI4723_CX13_A8_1_P1-1-I5    24608
# 15    UCI4723_CX13_A8_1_P4-1-E6    22976
# 16               Total Reads PF   504172
# /gale/netapp/seq2/illumina_runs/240605_M00412_0821_000000000-GLCPH_240605151421722198621 SALK085
#                         SampleID  # Reads
# 0   UCI4723_CX14_NAC_1_P13-1-I24   150098
# 1    UCI4723_CX14_NAC_1_P8-1-I15    78263
# 2    UCI4723_CX14_NAC_1_P7-1-A11    73609
# 3     UCI4723_CX14_NAC_1_P3-1-O5    71391
# 4     UCI4723_CX14_NAC_1_P4-1-C7    68212
# 5     UCI4723_CX14_NAC_1_P5-1-K9    67647
# 6     UCI4723_CX14_NAC_1_P6-1-M9    66764
# 7     UCI4723_CX14_NAC_1_P1-1-I3    59872
# 8     UCI4723_CX14_NAC_1_P2-1-E5    50667
# 9    UCI4723_CX14_NAC_1_P9-1-M14    44657
# 10   UCI4723_CX14_NAC_1_P16-1-J7    36805
# 11  UCI4723_CX14_NAC_1_P11-1-K20    36072
# 12  UCI4723_CX14_NAC_1_P10-1-K18    35265
# 13  UCI4723_CX14_NAC_1_P12-1-E22    32533
# 14   UCI4723_CX14_NAC_1_P15-1-L3    30412
# 15   UCI4723_CX14_NAC_1_P14-1-J3    28841
# 16                Total Reads PF   931108
#       Pool  Total Reads
# 0  SALK082       498618
# 1  SALK083      1633487
# 2  SALK084       504172
# 3  SALK085       931108

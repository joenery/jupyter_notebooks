# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240509_M00412_0813_000000000-GJVH2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
#    print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
#    generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240509_M00412_0813_000000000-GJVH2'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240509_M00412_0813_000000000-GJVH2_240509154220477449916 SALK065
#                              SampleID  # Reads
# 0       UWA7648_CX2325_THM2_1_P7-1-J7    59708
# 1   UWA7648_BS080910_MoTg_1_P11-1-K20    53162
# 2    UWA7648_BS080910_MoTg_1_P9-1-M14    52094
# 3     UWA7648_BS080910_MoTg_1_P5-1-K9    50083
# 4       UWA7648_CX2325_THM2_1_P6-1-L3    48329
# 5    UWA7648_BS080910_MoTg_1_P7-1-A11    48159
# 6    UWA7648_BS080910_MoTg_1_P8-1-I15    47975
# 7     UWA7648_BS080910_MoTg_1_P6-1-M9    47660
# 8     UWA7648_BS080910_MoTg_1_P3-1-O5    47325
# 9     UWA7648_BS080910_MoTg_1_P1-1-I3    47045
# 10      UWA7648_CX2325_THM2_1_P5-1-J3    45851
# 11    UWA7648_BS080910_MoTg_1_P4-1-C7    45761
# 12  UWA7648_BS080910_MoTg_1_P10-1-K18    44861
# 13  UWA7648_BS080910_MoTg_1_P13-1-I24    41846
# 14    UWA7648_BS080910_MoTg_1_P2-1-E5    40290
# 15  UWA7648_BS080910_MoTg_1_P12-1-E22    37652
# 16                     Total Reads PF   757801
# /gale/netapp/seq2/illumina_runs/240509_M00412_0813_000000000-GJVH2_240509154615034455945 SALK066
#                               SampleID  # Reads
# 0         UWA7648_BS02_MGM3_1_P6-1-K15    66922
# 1         UWA7648_BS02_MGM3_1_P7-1-M17    66024
# 2   UWA7648_CB67_Human_CBLP_1_P1-1-B11    64552
# 3    UWA7648_CB67_Human_CBLP_1_P5-1-D6    62047
# 4         UWA7648_BS02_MGM3_1_P8-1-C21    61559
# 5    UWA7648_CB67_Human_CBLP_1_P6-1-F6    61299
# 6    UWA7648_CB67_Human_CBLP_1_P7-1-H6    61001
# 7   UWA7648_CB67_Human_CBLP_1_P2-1-J11    60412
# 8         UWA7648_BS02_MGM3_1_P11-1-I2    60263
# 9        UWA7648_BS02_MGM3_1_P10-1-C23    60066
# 10       UWA7648_BS02_MGM3_1_P12-1-C10    58844
# 11        UWA7648_BS02_MGM3_1_P9-1-O21    58529
# 12   UWA7648_CB67_Human_CBLP_1_P3-1-J2    53540
# 13   UWA7648_CB67_Human_CBLP_1_P4-1-B6    52574
# 14   UWA7648_CB67_Human_CBLP_1_P8-1-D8    19763
# 15       UWA7648_BS02_MGM3_1_P13-1-G10    17300
# 16                      Total Reads PF   884695
# /gale/netapp/seq2/illumina_runs/240509_M00412_0813_000000000-GJVH2_240509154903050464229 SALK067
#                               SampleID  # Reads
# 0    UWA7648_CB60_Human_VeA_1_P13-1-E8   134795
# 1   UWA7648_CB60_Human_VeA_1_P10-1-E21   134147
# 2    UWA7648_CB60_Human_VeA_1_P7-1-N22   132089
# 3   UWA7648_CB60_Human_VeA_1_P14-1-K11   127621
# 4   UWA7648_CB60_Human_VeA_1_P12-1-P11   124761
# 5    UWA7648_CB60_Human_VeA_1_P1-1-J12   120771
# 6    UWA7648_CB60_Human_VeA_1_P4-1-B23   117957
# 7     UWA7648_CB60_Human_VeA_1_P3-1-F8   113494
# 8     UWA7648_CB60_Human_VeA_1_P2-1-A6   112939
# 9   UWA7648_CB60_Human_VeA_1_P15-1-K21   110603
# 10  UWA7648_CB60_Human_VeA_1_P16-1-C18   107583
# 11   UWA7648_CB60_Human_VeA_1_P5-1-P21    99266
# 12   UWA7648_CB60_Human_VeA_1_P8-1-F12    94789
# 13   UWA7648_CB60_Human_VeA_1_P9-1-F19    63457
# 14  UWA7648_CB60_Human_VeA_1_P11-1-F21    54282
# 15    UWA7648_CB60_Human_VeA_1_P6-1-G5    33158
# 16                      Total Reads PF  1681712
# /gale/netapp/seq2/illumina_runs/240509_M00412_0813_000000000-GJVH2_240510074552055298013 SALK064
#                          SampleID  # Reads
# 0    UWA7648_BS0304_PN_1_P6-1-A22    72052
# 1    UWA7648_BS0304_PN_1_P15-1-O4    69619
# 2     UWA7648_BS0304_PN_1_P1-1-I5    65628
# 3     UWA7648_BS0304_PN_1_P3-1-F3    65224
# 4    UWA7648_BS0304_PN_1_P5-1-G17    63713
# 5     UWA7648_BS0304_PN_1_P4-1-E6    61783
# 6   UWA7648_BS0304_PN_1_P16-1-J18    61431
# 7    UWA7648_BS0304_PN_1_P2-1-P13    60949
# 8   UWA7648_BS0304_PN_1_P10-1-I17    60859
# 9    UWA7648_BS0304_PN_1_P14-1-P6    60621
# 10   UWA7648_BS0304_PN_1_P7-1-B19    60132
# 11  UWA7648_BS0304_PN_1_P13-1-J24    59269
# 12    UWA7648_BS0304_PN_1_P8-1-A7    58960
# 13   UWA7648_BS0304_PN_1_P11-1-E9    58431
# 14   UWA7648_BS0304_PN_1_P12-1-N8    54389
# 15    UWA7648_BS0304_PN_1_P9-1-G9    53966
# 16                 Total Reads PF   987026
#       Pool  Total Reads
# 0  SALK065       757801
# 1  SALK066       884695
# 2  SALK067      1681712
# 3  SALK064       987026

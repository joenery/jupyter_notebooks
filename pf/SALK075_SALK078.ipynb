# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240606_M00412_0822_000000000-DLH2M'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240606_M00412_0822_000000000-DLH2M'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240606_M00412_0822_000000000-DLH2M_240607080133531678474 SALK075
#                         SampleID  # Reads
# 0    UCI4723_CX04_A32_1_P7-1-N22    20781
# 1    UCI4723_CX04_A32_1_P5-1-P21    19067
# 2    UCI4723_CX04_A32_1_P4-1-B23    18593
# 3    UCI4723_CX04_A32_1_P1-1-J12    18382
# 4    UCI4723_CX04_A32_1_P9-1-F19    18025
# 5     UCI4723_CX04_A32_1_P2-1-A6    17681
# 6     UCI4723_CX04_A32_1_P3-1-F8    17429
# 7     UCI4723_CX04_A32_1_P6-1-G5    17411
# 8    UCI4723_CX04_A32_1_P8-1-F12    17268
# 9   UCI4723_CX04_A32_1_P10-1-E21    16597
# 10   UCI4723_CX04_A32_1_P13-1-E8    16239
# 11  UCI4723_CX04_A32_1_P16-1-C18    16064
# 12  UCI4723_CX04_A32_1_P11-1-F21    15923
# 13  UCI4723_CX04_A32_1_P14-1-K11    15362
# 14  UCI4723_CX04_A32_1_P15-1-K21    15109
# 15  UCI4723_CX04_A32_1_P12-1-P11    14915
# 16                Total Reads PF   274846
# /gale/netapp/seq2/illumina_runs/240606_M00412_0822_000000000-DLH2M_240607080539909202356 SALK078
#                        SampleID  # Reads
# 0    UCI4723_CX06_A9_1_P16-1-D8    31426
# 1    UCI4723_CX06_A9_1_P15-1-H6    25804
# 2    UCI4723_CX06_A9_1_P7-1-C10    25790
# 3     UCI4723_CX06_A9_1_P6-1-I2    24888
# 4    UCI4723_CX06_A9_1_P8-1-G10    24732
# 5   UCI4723_CX06_A9_1_P10-1-J11    23855
# 6    UCI4723_CX06_A9_1_P14-1-F6    23174
# 7    UCI4723_CX06_A9_1_P4-1-O21    22051
# 8    UCI4723_CX06_A9_1_P2-1-M17    21828
# 9    UCI4723_CX06_A9_1_P5-1-C23    21484
# 10   UCI4723_CX06_A9_1_P11-1-J2    21467
# 11   UCI4723_CX06_A9_1_P1-1-K15    20955
# 12   UCI4723_CX06_A9_1_P13-1-D6    20836
# 13   UCI4723_CX06_A9_1_P9-1-B11    20545
# 14   UCI4723_CX06_A9_1_P12-1-B6    20401
# 15   UCI4723_CX06_A9_1_P3-1-C21    20355
# 16               Total Reads PF   369591
#       Pool  Total Reads
# 0  SALK075       274846
# 1  SALK078       369591

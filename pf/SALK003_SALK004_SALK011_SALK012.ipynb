# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("231220_M00412_0759_000000000-GJ2RG_240116123920677353949", "SALK003"),
    ("231220_M00412_0759_000000000-GJ2RG_240116123922583026638", "SALK004"),
    ("231220_M00412_0759_000000000-GJ2RG_240116123923631489956", "SALK011"),
    ("231220_M00412_0759_000000000-GJ2RG_240116123923631489956", "SALK011")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                         SampleID  # Reads
# 0     UWA7648_CX17_A38_1_P3-1-O5    38897
# 1    UWA7648_CX17_A38_1_P7-1-A11    36484
# 2    UWA7648_CX17_A38_1_P8-1-I15    36434
# 3     UWA7648_CX17_A38_1_P4-1-C7    34034
# 4     UWA7648_CX17_A38_1_P6-1-M9    31969
# 5    UWA7648_CX17_A38_2_P14-1-I2    30256
# 6     UWA7648_CX17_A38_1_P1-1-I3    29083
# 7     UWA7648_CX17_A38_1_P5-1-K9    27809
# 8   UWA7648_CX17_A38_2_P15-1-C10    26216
# 9     UWA7648_CX17_A38_1_P2-1-E5    25062
# 10  UWA7648_CX17_A38_2_P12-1-O21    25032
# 11  UWA7648_CX17_A38_2_P13-1-C23    23788
# 12  UWA7648_CX17_A38_2_P16-1-G10    23765
# 13  UWA7648_CX17_A38_2_P11-1-C21    22896
# 14   UWA7648_CX17_A38_1_P9-1-K15    22327
# 15  UWA7648_CX17_A38_2_P10-1-M17    22110
# 16                Total Reads PF   456162
#                         SampleID  # Reads
# 0     UWA7648_CX14_A45_1_P6-1-I2    27770
# 1    UWA7648_CX14_A45_2_P14-1-F6    26676
# 2    UWA7648_CX14_A45_2_P16-1-D8    25130
# ...

# %%
# !pwd
# Out:
# /gale/netapp/home/seq/jupyter_notebooks

# %%
# !ls
# Out:
# output_file.csv
# pf.py
# plot_reads_function.ipynb
# plot_reads_pf.ipynb
# Pool_AD3C_95_96_Pool_AD3C_97_98.ipynb
# __pycache__
# reads_plot.ipynb
# reverse_complement.py
# reverse_complement.py.old
# SALK003_004_011_012-231218.ipynb
# SALK003_SALK004_SALK011_SALK012_231218.ipynb
# SALK003_SALK004_SALK011_SALK012.ipynb
# SALK011_SALK012_231220_failed.ipynb
# SALK011_SALK012_SALK013_231213.ipynb
# SALK014_SALK015_BigFootTest1.ipynb
# SALK015_reads_pf.png
# SALK016_SALK017_failed.ipynb
# SALK016_SALK017_SALK018.ipynb
# SALK019_SALK020_SALK021_BigfootTest2.ipynb
# SALK022_SALK023_SALK024.ipynb
# SALK_11_12_3_4.ipynb
# SALK_7_8_9_10.ipynb
# Untitled2.ipynb
# Untitled3.ipynb

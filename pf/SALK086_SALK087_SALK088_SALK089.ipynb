# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240611_M00412_0824_000000000-GLCNP'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240611_M00412_0824_000000000-GLCNP_240611152420557112664 SALK086
#                            SampleID  # Reads
# 0   UCI4723_CX151617_BF_1_P10-1-J11    84996
# 1    UCI4723_CX151617_BF_1_P7-1-C10    84212
# 2    UCI4723_CX151617_BF_1_P14-1-F6    82613
# 3    UCI4723_CX151617_BF_1_P5-1-C23    82188
# 4    UCI4723_CX151617_BF_1_P1-1-K15    82018
# 5    UCI4723_CX151617_BF_1_P11-1-J2    79602
# 6    UCI4723_CX151617_BF_1_P13-1-D6    77891
# 7    UCI4723_CX151617_BF_1_P9-1-B11    76994
# 8     UCI4723_CX151617_BF_1_P6-1-I2    76622
# 9    UCI4723_CX151617_BF_1_P3-1-C21    76495
# 10   UCI4723_CX151617_BF_1_P2-1-M17    75749
# 11   UCI4723_CX151617_BF_1_P8-1-G10    74800
# 12   UCI4723_CX151617_BF_1_P12-1-B6    73378
# 13   UCI4723_CX151617_BF_1_P15-1-H6    70867
# 14   UCI4723_CX151617_BF_1_P16-1-D8    69795
# 15   UCI4723_CX151617_BF_1_P4-1-O21    67273
# 16                   Total Reads PF  1235493
# /gale/netapp/seq2/illumina_runs/240611_M00412_0824_000000000-GLCNP_240611152552413427680 SALK087
#                         SampleID  # Reads
# 0    UCI4723_CX07_A24_1_P8-1-F12    45744
# 1   UCI4723_CX07_A24_1_P14-1-K11    43377
# 2    UCI4723_CX07_A24_1_P5-1-P21    42907
# 3    UCI4723_CX07_A24_1_P4-1-B23    42155
# 4    UCI4723_CX07_A24_1_P13-1-E8    40919
# 5    UCI4723_CX07_A24_1_P1-1-J12    40816
# 6   UCI4723_CX07_A24_1_P16-1-C18    40474
# 7   UCI4723_CX07_A24_1_P12-1-P11    39926
# 8    UCI4723_CX07_A24_1_P7-1-N22    39413
# 9     UCI4723_CX07_A24_1_P6-1-G5    39123
# 10    UCI4723_CX07_A24_1_P3-1-F8    37020
# 11   UCI4723_CX07_A24_1_P9-1-F19    34954
# 12  UCI4723_CX07_A24_1_P15-1-K21    34237
# 13    UCI4723_CX07_A24_1_P2-1-A6    33958
# 14  UCI4723_CX07_A24_1_P10-1-E21    33135
# 15  UCI4723_CX07_A24_1_P11-1-F21    26584
# 16                Total Reads PF   614742
# /gale/netapp/seq2/illumina_runs/240611_M00412_0824_000000000-GLCNP_240611152636581358771 SALK088
#                         SampleID  # Reads
# 0   UCI4723_CX13_A38_1_P16-1-J18    71012
# 1    UCI4723_CX13_A38_1_P6-1-A22    69440
# 2     UCI4723_CX13_A38_1_P9-1-G9    68409
# 3   UCI4723_CX13_A38_1_P10-1-I17    67188
# 4     UCI4723_CX13_A38_1_P3-1-F3    66133
# 5   UCI4723_CX13_A38_1_P13-1-J24    65651
# 6    UCI4723_CX13_A38_1_P14-1-P6    65100
# 7    UCI4723_CX13_A38_1_P15-1-O4    64343
# 8    UCI4723_CX13_A38_1_P11-1-E9    63341
# 9    UCI4723_CX13_A38_1_P12-1-N8    62705
# 10   UCI4723_CX13_A38_1_P5-1-G17    62042
# 11   UCI4723_CX13_A38_1_P7-1-B19    57712
# 12    UCI4723_CX13_A38_1_P8-1-A7    48905
# 13    UCI4723_CX13_A38_1_P4-1-E6    48705
# 14    UCI4723_CX13_A38_1_P1-1-I5    42419
# 15   UCI4723_CX13_A38_1_P2-1-P13     2587
# 16                Total Reads PF   925692
# /gale/netapp/seq2/illumina_runs/240611_M00412_0824_000000000-GLCNP_240611152734277025995 SALK089
#                            SampleID  # Reads
# 0     UCI4723_CX151618_GP_1_P1-1-I3   113868
# 1     UCI4723_CX151618_GP_1_P5-1-K9   112089
# 2     UCI4723_CX151618_GP_1_P6-1-M9   105797
# 3    UCI4723_CX151618_GP_1_P7-1-A11   103956
# 4    UCI4723_CX151618_GP_1_P8-1-I15   103322
# 5     UCI4723_CX151618_GP_1_P3-1-O5    98890
# 6    UCI4723_CX151618_GP_1_P9-1-M14    98160
# 7     UCI4723_CX151618_GP_1_P4-1-C7    96709
# 8     UCI4723_CX151618_GP_1_P2-1-E5    94303
# 9    UCI4723_CX151618_GP_1_P16-1-J7    92565
# 10  UCI4723_CX151618_GP_1_P10-1-K18    92119
# 11  UCI4723_CX151618_GP_1_P13-1-I24    90518
# 12   UCI4723_CX151618_GP_1_P14-1-J3    88144
# 13   UCI4723_CX151618_GP_1_P15-1-L3    84264
# 14  UCI4723_CX151618_GP_1_P12-1-E22    82520
# 15  UCI4723_CX151618_GP_1_P11-1-K20    80907
# 16                   Total Reads PF  1538131
#       Pool  Total Reads
# 0  SALK086      1235493
# 1  SALK087       614742
# 2  SALK088       925692
# 3  SALK089      1538131

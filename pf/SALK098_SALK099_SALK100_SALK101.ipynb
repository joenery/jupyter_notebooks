# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart, generate_read_adj_table
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240625_M00412_0827_000000000-GLBHM'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
summary_df
# Out:
# /gale/netapp/seq2/illumina_runs/240625_M00412_0827_000000000-GLBHM_240626074242234334075 SALK099
#                          SampleID  # Reads
# 0   UCI4723_CX1416_Pu_1_P11-1-F21    52180
# 1    UCI4723_CX1416_Pu_2_P2-1-K11    51581
# 2     UCI4723_CX1416_Pu_2_P1-1-E8    50167
# 3   UCI4723_CX1416_Pu_1_P10-1-E21    49748
# 4     UCI4723_CX1416_Pu_1_P6-1-G5    47575
# 5    UCI4723_CX1416_Pu_1_P9-1-F19    46850
# 6    UCI4723_CX1416_Pu_2_P4-1-C18    46273
# 7    UCI4723_CX1416_Pu_2_P3-1-K21    44723
# 8    UCI4723_CX1416_Pu_1_P5-1-P21    43783
# 9   UCI4723_CX1416_Pu_1_P12-1-P11    42577
# 10   UCI4723_CX1416_Pu_1_P8-1-F12    41110
# 11   UCI4723_CX1416_Pu_1_P4-1-B23    38957
# 12    UCI4723_CX1416_Pu_1_P2-1-A6    35652
# 13   UCI4723_CX1416_Pu_1_P7-1-N22    35529
# 14   UCI4723_CX1416_Pu_1_P1-1-J12    33596
# 15    UCI4723_CX1416_Pu_1_P3-1-F8    24532
# 16                 Total Reads PF   684833
# /gale/netapp/seq2/illumina_runs/240625_M00412_0827_000000000-GLBHM_240626074844697205439 SALK098
#                         SampleID  # Reads
# 0    UCI4723_CX20_S1C_1_P16-1-D8   129793
# 1    UCI4723_CX20_S1C_1_P9-1-B11   116855
# 2    UCI4723_CX20_S1C_1_P15-1-H6   113896
# 3    UCI4723_CX20_S1C_1_P2-1-M17   113512
# 4   UCI4723_CX20_S1C_1_P10-1-J11   113225
# 5    UCI4723_CX20_S1C_1_P5-1-C23   112975
# 6    UCI4723_CX20_S1C_1_P14-1-F6   109996
# 7    UCI4723_CX20_S1C_1_P12-1-B6   107866
# 8    UCI4723_CX20_S1C_1_P7-1-C10   106971
# 9    UCI4723_CX20_S1C_1_P8-1-G10   106639
# 10   UCI4723_CX20_S1C_1_P3-1-C21   106286
# 11    UCI4723_CX20_S1C_1_P6-1-I2   105435
# 12   UCI4723_CX20_S1C_1_P4-1-O21   105361
# 13   UCI4723_CX20_S1C_1_P13-1-D6   102508
# 14   UCI4723_CX20_S1C_1_P11-1-J2   101475
# 15   UCI4723_CX20_S1C_1_P1-1-K15    99422
# 16                Total Reads PF  1752215
# /gale/netapp/seq2/illumina_runs/240625_M00412_0827_000000000-GLBHM_240626075252838882156 SALK100
#                             SampleID  # Reads
# 0   UCI4723_CX141517_Cla_1_P16-1-J18    85796
# 1    UCI4723_CX141517_Cla_1_P15-1-O4    81423
# 2    UCI4723_CX141517_Cla_1_P14-1-P6    72193
# 3   UCI4723_CX141517_Cla_1_P13-1-J24    66732
# 4    UCI4723_CX141517_Cla_1_P11-1-E9    57822
# 5   UCI4723_CX141517_Cla_1_P10-1-I17    55620
# 6     UCI4723_CX141517_Cla_1_P9-1-G9    48619
# 7    UCI4723_CX141517_Cla_1_P12-1-N8    41986
# 8    UCI4723_CX141517_Cla_1_P6-1-A22    39187
# 9    UCI4723_CX141517_Cla_1_P7-1-B19    20313
# 10   UCI4723_CX141517_Cla_1_P5-1-G17    17902
# 11   UCI4723_CX141517_Cla_1_P2-1-P13    16211
# 12    UCI4723_CX141517_Cla_1_P4-1-E6    15516
# 13    UCI4723_CX141517_Cla_1_P1-1-I5    14141
# 14    UCI4723_CX141517_Cla_1_P3-1-F3    13300
# 15    UCI4723_CX141517_Cla_1_P8-1-A7    13139
# 16                    Total Reads PF   659900
# /gale/netapp/seq2/illumina_runs/240625_M00412_0827_000000000-GLBHM_240626075533182982711 SALK101
#                        SampleID  # Reads
# 0   UCI4723_CX28_A5_1_P10-1-K18    82568
# 1    UCI4723_CX28_A5_1_P8-1-I15    75215
# 2    UCI4723_CX28_A5_1_P7-1-A11    75185
# 3     UCI4723_CX28_A5_1_P5-1-K9    71299
# 4     UCI4723_CX28_A5_1_P6-1-M9    64761
# 5    UCI4723_CX28_A5_1_P15-1-L3    64096
# 6    UCI4723_CX28_A5_1_P9-1-M14    63757
# 7   UCI4723_CX28_A5_1_P12-1-E22    63145
# 8   UCI4723_CX28_A5_1_P11-1-K20    63079
# 9     UCI4723_CX28_A5_1_P3-1-O5    61843
# 10   UCI4723_CX28_A5_1_P16-1-J7    60789
# 11    UCI4723_CX28_A5_1_P1-1-I3    59764
# 12   UCI4723_CX28_A5_1_P14-1-J3    57676
# 13    UCI4723_CX28_A5_1_P2-1-E5    57636
# 14  UCI4723_CX28_A5_1_P13-1-I24    56343
# 15    UCI4723_CX28_A5_1_P4-1-C7    56206
# 16               Total Reads PF  1033362
#       Pool  Total Reads
# 0  SALK099       684833
# 1  SALK098      1752215
# 2  SALK100       659900
# 3  SALK101      1033362

# %%
generate_read_adj_table(summary_df)
# Out:
#         Pool Combo     Pool  Total Reads  Read adj factor
# 0  SALK098_SALK101  SALK098      1752215         0.589746
# 1  SALK098_SALK101  SALK101      1033362         1.695645
# 2  SALK099_SALK100  SALK099       684833         0.963593
# 3  SALK099_SALK100  SALK100       659900         1.037783

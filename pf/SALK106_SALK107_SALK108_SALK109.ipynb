# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart, generate_read_adj_table
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240712_M00412_0834_000000000-GLBGF'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
summary_df
# Out:
# /gale/netapp/seq2/illumina_runs/240712_M00412_0834_000000000-GLBGF_240712131828928975356 SALK106
#                            SampleID  # Reads
# 0    UCI4723_CX1718_AMY2_1_P16-1-D8    90388
# 1    UCI4723_CX1718_AMY2_1_P1-1-K15    86904
# 2    UCI4723_CX1718_AMY2_1_P7-1-C10    85898
# 3    UCI4723_CX1718_AMY2_1_P2-1-M17    80907
# 4    UCI4723_CX1718_AMY2_1_P8-1-G10    79773
# 5    UCI4723_CX1718_AMY2_1_P3-1-C21    77009
# 6    UCI4723_CX1718_AMY2_1_P9-1-B11    76341
# 7     UCI4723_CX1718_AMY2_1_P6-1-I2    75266
# 8    UCI4723_CX1718_AMY2_1_P12-1-B6    74933
# 9    UCI4723_CX1718_AMY2_1_P14-1-F6    74144
# 10  UCI4723_CX1718_AMY2_1_P10-1-J11    73328
# 11   UCI4723_CX1718_AMY2_1_P4-1-O21    70962
# 12   UCI4723_CX1718_AMY2_1_P5-1-C23    68637
# 13   UCI4723_CX1718_AMY2_1_P13-1-D6    68636
# 14   UCI4723_CX1718_AMY2_1_P15-1-H6    62971
# 15   UCI4723_CX1718_AMY2_1_P11-1-J2    56885
# 16                   Total Reads PF  1202982
# /gale/netapp/seq2/illumina_runs/240712_M00412_0834_000000000-GLBGF_240712131851765476088 SALK107
#                          SampleID  # Reads
# 0    UCI4723_CX3842_V2_1_P7-1-N22    93206
# 1   UCI4723_CX3842_V2_1_P14-1-K11    92754
# 2    UCI4723_CX3842_V2_1_P5-1-P21    85920
# 3    UCI4723_CX3842_V2_1_P4-1-B23    84625
# 4   UCI4723_CX3842_V2_1_P16-1-C18    79815
# 5   UCI4723_CX3842_V2_1_P11-1-F21    79420
# 6     UCI4723_CX3842_V2_1_P6-1-G5    78757
# 7   UCI4723_CX3842_V2_1_P12-1-P11    78467
# 8    UCI4723_CX3842_V2_1_P8-1-F12    76797
# 9    UCI4723_CX3842_V2_1_P1-1-J12    76611
# 10   UCI4723_CX3842_V2_1_P13-1-E8    76439
# 11    UCI4723_CX3842_V2_1_P3-1-F8    68377
# 12  UCI4723_CX3842_V2_1_P10-1-E21    65917
# 13   UCI4723_CX3842_V2_1_P9-1-F19    61092
# 14  UCI4723_CX3842_V2_1_P15-1-K21    60426
# 15    UCI4723_CX3842_V2_1_P2-1-A6    44625
# 16                 Total Reads PF  1203248
# /gale/netapp/seq2/illumina_runs/240712_M00412_0834_000000000-GLBGF_240712131901461831471 SALK108
#                         SampleID  # Reads
# 0    UCI4723_CX41_PSC_1_P2-1-P13    75886
# 1    UCI4723_CX41_PSC_1_P6-1-A22    71489
# 2     UCI4723_CX41_PSC_1_P3-1-F3    65819
# 3    UCI4723_CX41_PSC_1_P15-1-O4    62991
# 4     UCI4723_CX41_PSC_1_P4-1-E6    53559
# 5     UCI4723_CX41_PSC_1_P1-1-I5    52811
# 6    UCI4723_CX41_PSC_1_P5-1-G17    52470
# 7     UCI4723_CX41_PSC_1_P8-1-A7    51986
# 8   UCI4723_CX41_PSC_1_P16-1-J18    50956
# 9    UCI4723_CX41_PSC_1_P14-1-P6    49447
# 10  UCI4723_CX41_PSC_1_P13-1-J24    49177
# 11   UCI4723_CX41_PSC_1_P7-1-B19    49046
# 12   UCI4723_CX41_PSC_1_P11-1-E9    46682
# 13    UCI4723_CX41_PSC_1_P9-1-G9    44789
# 14  UCI4723_CX41_PSC_1_P10-1-I17    44519
# 15   UCI4723_CX41_PSC_1_P12-1-N8    43701
# 16                Total Reads PF   865328
# /gale/netapp/seq2/illumina_runs/240712_M00412_0834_000000000-GLBGF_240712131911149525551 SALK109
#                         SampleID  # Reads
# 0    UCI4723_CX40_V1C_1_P8-1-I15    72226
# 1    UCI4723_CX40_V1C_1_P15-1-L3    69924
# 2     UCI4723_CX40_V1C_1_P6-1-M9    68863
# 3   UCI4723_CX40_V1C_1_P11-1-K20    68667
# 4     UCI4723_CX40_V1C_1_P5-1-K9    68317
# 5    UCI4723_CX40_V1C_1_P7-1-A11    67953
# 6    UCI4723_CX40_V1C_1_P16-1-J7    66201
# 7     UCI4723_CX40_V1C_1_P1-1-I3    64501
# 8     UCI4723_CX40_V1C_1_P4-1-C7    60248
# 9    UCI4723_CX40_V1C_1_P9-1-M14    60000
# 10    UCI4723_CX40_V1C_1_P3-1-O5    59549
# 11   UCI4723_CX40_V1C_1_P14-1-J3    58635
# 12  UCI4723_CX40_V1C_1_P12-1-E22    58149
# 13  UCI4723_CX40_V1C_1_P13-1-I24    57829
# 14  UCI4723_CX40_V1C_1_P10-1-K18    55335
# 15    UCI4723_CX40_V1C_1_P2-1-E5    50745
# 16                Total Reads PF  1007142
#       Pool  Total Reads
# 0  SALK106      1202982
# 1  SALK107      1203248
# 2  SALK108       865328
# 3  SALK109      1007142

# %%
generate_read_adj_table(summary_df)
# Out:
#         Pool Combo     Pool  Total Reads  Read adj factor
# 0  SALK106_SALK107  SALK106      1202982         1.000221
# 1  SALK106_SALK107  SALK107      1203248         0.999779
# 2  SALK108_SALK109  SALK108       865328         1.163885
# 3  SALK108_SALK109  SALK109      1007142         0.859192

# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("240124_M00412_0777_000000000-GJT6T_240125092921774355423", "SALK028"),
    ("240124_M00412_0777_000000000-GJT6T_240125092925506828629", "SALK029"),
    ("240124_M00412_0777_000000000-GJT6T_240125092927057755859", "SALK030"),
    ("240124_M00412_0777_000000000-GJT6T_240125100208990927022", "Pool_AD3C_103_104")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                            SampleID  # Reads
# 0    UWA7648_CX2324_THM1_1_P1-1-J12   120261
# 1    UWA7648_CX2324_THM1_1_P4-1-B23   113911
# 2    UWA7648_CX2324_THM1_1_P9-1-F19   104909
# 3     UWA7648_CX2324_THM1_1_P3-1-F8   101844
# 4    UWA7648_CX2324_THM1_1_P8-1-F12    98466
# 5     UWA7648_CX2324_THM1_1_P6-1-G5    95768
# 6     UWA7648_CX2324_THM1_1_P2-1-A6    94350
# 7    UWA7648_CX2324_THM1_1_P5-1-P21    89363
# 8    UWA7648_CX2324_THM1_1_P13-1-E8    80403
# 9   UWA7648_CX2324_THM1_1_P16-1-C18    79771
# 10  UWA7648_CX2324_THM1_1_P12-1-P11    79066
# 11  UWA7648_CX2324_THM1_1_P14-1-K11    78959
# 12  UWA7648_CX2324_THM1_1_P15-1-K21    72665
# 13  UWA7648_CX2324_THM1_1_P10-1-E21    69797
# 14  UWA7648_CX2324_THM1_1_P11-1-F21    58695
# 15   UWA7648_CX2324_THM1_1_P7-1-N22     1200
# 16                   Total Reads PF  1339428
#                         SampleID  # Reads
# 0     UWA7648_CX41_PSC_2_P3-1-F3    84535
# 1    UWA7648_CX41_PSC_2_P6-1-A22    83557
# ...

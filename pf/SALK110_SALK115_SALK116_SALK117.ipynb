# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart, generate_read_adj_table
import pandas as pd

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240718_M00412_0837_000000000-GLBHC'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame sorted by the Pool column
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads']).sort_values(by='Pool')

# Print the summary table
summary_df
# Out:
# /gale/netapp/seq2/illumina_runs/240718_M00412_0837_000000000-GLBHC_240719084110651514190 SALK117
# /gale/netapp/seq2/illumina_runs/240718_M00412_0837_000000000-GLBHC_240719084121193040412 SALK116
# /gale/netapp/seq2/illumina_runs/240718_M00412_0837_000000000-GLBHC_240719084132043420494 SALK115
# /gale/netapp/seq2/illumina_runs/240718_M00412_0837_000000000-GLBHC_240719084142760179942 SALK110
#       Pool  Total Reads
# 3  SALK110       733750
# 2  SALK115      1239350
# 1  SALK116      1429377
# 0  SALK117       568627

# %%
generate_read_adj_table(summary_df)
# Out:
#     Pool 1   Pool 2  Total Reads     Ratio
# 0  SALK110  SALK117       733750  0.774960
# 2  SALK115  SALK116      1239350  1.153328
# 3  SALK116  SALK115      1429377  0.867056
# 1  SALK117  SALK110       568627  1.290389
# 0  SALK110  SALK116       733750  1.948044
# 2  SALK115  SALK117      1239350  0.458811
# 1  SALK116  SALK110      1429377  0.513336
# 3  SALK117  SALK115       568627  2.179548

# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240523_M00412_0818_000000000-GK85W/'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
#    print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
#    generate_reads_pf_chart(run_folder, pool)
# Out:
# /gale/netapp/seq2/illumina_runs/240523_M00412_0818_000000000-GK85W_240528134254685680174 SALK070
#                                SampleID  # Reads
# 0    UWA7648_CB67_Human_CBLA_1_P16-1-D8   101521
# 1    UWA7648_CB67_Human_CBLA_1_P9-1-B11    94551
# 2    UWA7648_CB67_Human_CBLA_1_P13-1-D6    93476
# 3    UWA7648_CB67_Human_CBLA_1_P15-1-H6    92782
# 4   UWA7648_CB67_Human_CBLA_1_P10-1-J11    91483
# 5    UWA7648_CB67_Human_CBLA_1_P14-1-F6    91203
# 6    UWA7648_CB67_Human_CBLA_1_P5-1-C23    90463
# 7     UWA7648_CB67_Human_CBLA_1_P6-1-I2    90438
# 8    UWA7648_CB67_Human_CBLA_1_P1-1-K15    90285
# 9    UWA7648_CB67_Human_CBLA_1_P7-1-C10    87144
# 10   UWA7648_CB67_Human_CBLA_1_P3-1-C21    84922
# 11   UWA7648_CB67_Human_CBLA_1_P12-1-B6    84498
# 12   UWA7648_CB67_Human_CBLA_1_P2-1-M17    83469
# 13   UWA7648_CB67_Human_CBLA_1_P4-1-O21    82745
# 14   UWA7648_CB67_Human_CBLA_1_P8-1-G10    78148
# 15   UWA7648_CB67_Human_CBLA_1_P11-1-J2    78132
# 16                       Total Reads PF  1415260
# /gale/netapp/seq2/illumina_runs/240523_M00412_0818_000000000-GK85W_240528134636344751678 SALK071
#                                SampleID  # Reads
# 0    UWA7648_CB61626364_CbDN_1_P9-1-F19    42395
# 1    UWA7648_CB61626364_CbDN_1_P5-1-P21    41631
# 2    UWA7648_CB61626364_CbDN_1_P7-1-N22    39776
# 3    UWA7648_CB61626364_CbDN_1_P4-1-B23    38378
# 4    UWA7648_CB61626364_CbDN_1_P13-1-E8    37108
# 5    UWA7648_CB61626364_CbDN_1_P8-1-F12    36703
# 6   UWA7648_CB61626364_CbDN_1_P16-1-C18    36371
# 7   UWA7648_CB61626364_CbDN_1_P10-1-E21    35733
# 8   UWA7648_CB61626364_CbDN_1_P15-1-K21    35359
# 9   UWA7648_CB61626364_CbDN_1_P14-1-K11    35298
# 10  UWA7648_CB61626364_CbDN_1_P11-1-F21    34075
# 11   UWA7648_CB61626364_CbDN_1_P1-1-J12    33973
# 12    UWA7648_CB61626364_CbDN_1_P3-1-F8    33900
# 13  UWA7648_CB61626364_CbDN_1_P12-1-P11    33715
# 14    UWA7648_CB61626364_CbDN_1_P6-1-G5    33621
# 15    UWA7648_CB61626364_CbDN_1_P2-1-A6    32968
# 16                       Total Reads PF   581004
# /gale/netapp/seq2/illumina_runs/240523_M00412_0818_000000000-GK85W_240528135710925454346 SALK072
#                              SampleID  # Reads
# 0       UWA7648_CX27_THM4_2_P16-1-J18    89129
# 1        UWA7648_CX27_THM4_2_P15-1-O4    81836
# 2    UWA7648_BS080910_MoTg_2_P15-1-E9    73391
# 3         UWA7648_CX20_BF_2_P15-1-A22    72174
# 4          UWA7648_CX20_BF_2_P12-1-F3    71088
# 5   UWA7648_BS080910_MoTg_2_P14-1-I17    70902
# 6   UWA7648_BS080910_MoTg_2_P17-1-J24    69492
# 7          UWA7648_CX20_BF_2_P18-1-G9    68913
# 8      UWA7648_BS0102_MGM1_2_P17-1-P6    68114
# 9         UWA7648_CX20_BF_2_P11-1-P13    67292
# 10   UWA7648_BS080910_MoTg_2_P16-1-N8    65367
# 11        UWA7648_CX20_BF_2_P16-1-B19    62784
# 12         UWA7648_CX20_BF_2_P17-1-A7    61021
# 13         UWA7648_CX20_BF_2_P10-1-I5    60756
# 14        UWA7648_CX20_BF_2_P14-1-G17    60447
# 15         UWA7648_CX20_BF_2_P13-1-E6    59484
# 16                     Total Reads PF  1102190
# /gale/netapp/seq2/illumina_runs/240523_M00412_0818_000000000-GK85W_240528140157565986179 SALK073
#                            SampleID  # Reads
# 0      UWA7648_CB67_CBLP_2_P13-1-K9   106524
# 1      UWA7648_CB67_CBLP_2_P11-1-O5    90512
# 2     UWA7648_CB67_CBLP_2_P17-1-M14    88116
# 3       UWA7648_CB67_CBLP_2_P9-1-I3    87374
# 4      UWA7648_CX41_PSC_2_P15-1-K18    86804
# 5     UWA7648_CB67_CBLP_2_P16-1-I15    86453
# 6      UWA7648_CB67_CBLP_2_P10-1-E5    80075
# 7      UWA7648_CX41_PSC_2_P16-1-K20    77576
# 8     UWA7648_CB67_CBLP_2_P15-1-A11    76715
# 9      UWA7648_CB67_CBLP_2_P12-1-C7    73480
# 10     UWA7648_CB67_CBLP_2_P14-1-M9    70533
# 11      UWA7648_CX17_A44_2_P1-1-I24    69796
# 12      UWA7648_CX14_A45_1_P17-1-L3    68713
# 13       UWA7648_CX17_A44_2_P2-1-J3    67680
# 14      UWA7648_CX35_Pro_2_P17-1-J7    67286
# 15  UWA7648_CX3132_PPHC_2_P15-1-E22    65995
# 16                   Total Reads PF  1263632

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240523_M00412_0818_000000000-GK85W'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240523_M00412_0818_000000000-GK85W'
#       2 # List of tuples for run folders and pools
# ----> 3 run_folder_pool_pairs = get_pool_ids_from_directories(runs)
#       5 # Initialize a list to store total reads for each pool
#       6 pool_totals = []
#
# NameError: name 'get_pool_ids_from_directories' is not defined

# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("231213_M00412_0753_000000000-GHWHG_231214135838934889663", "SALK011"),
    ("231213_M00412_0753_000000000-GHWHG_231214140058326380532", "SALK012"),
    ("231213_M00412_0753_000000000-GHWHG_231214140100761923934", "SALK013"),
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                            SampleID  # Reads
# 0   UWA7648_CX242526_Ig_1_P11-1-F21    22664
# 1    UWA7648_CX242526_Ig_1_P8-1-F12    21399
# 2    UWA7648_CX242526_Ig_1_P13-1-E8    21375
# 3    UWA7648_CX242526_Ig_1_P9-1-F19    21368
# 4   UWA7648_CX242526_Ig_1_P16-1-C18    20147
# 5   UWA7648_CX242526_Ig_1_P14-1-K11    19640
# 6     UWA7648_CX242526_Ig_1_P2-1-A6    18605
# 7    UWA7648_CX242526_Ig_1_P5-1-P21    18433
# 8   UWA7648_CX242526_Ig_1_P10-1-E21    17973
# 9   UWA7648_CX242526_Ig_1_P15-1-K21    17901
# 10   UWA7648_CX242526_Ig_1_P4-1-B23    17364
# 11   UWA7648_CX242526_Ig_1_P1-1-J12    16511
# 12    UWA7648_CX242526_Ig_1_P6-1-G5    16327
# 13   UWA7648_CX242526_Ig_1_P7-1-N22    14769
# 14  UWA7648_CX242526_Ig_1_P12-1-P11    14099
# 15    UWA7648_CX242526_Ig_1_P3-1-F8    11444
# 16                   Total Reads PF   290019
#                        SampleID  # Reads
# 0     UWA7648_CX29_A5_1_P4-1-E6    68206
# 1     UWA7648_CX29_A5_1_P3-1-F3    67552
# 2    UWA7648_CX29_A5_1_P11-1-E9    49880
# 3   UWA7648_CX29_A5_1_P10-1-I17    45103
# 4     UWA7648_CX29_A5_1_P9-1-G9    43635
# 5    UWA7648_CX29_A5_1_P6-1-A22    41417
# 6    UWA7648_CX29_A5_1_P14-1-P6    41077
# 7    UWA7648_CX29_A5_1_P7-1-B19    39337
# 8   UWA7648_CX29_A5_1_P13-1-J24    38643
# 9    UWA7648_CX29_A5_2_P15-1-O4    38053
# 10   UWA7648_CX29_A5_1_P12-1-N8    36442
# 11   UWA7648_CX29_A5_1_P5-1-G17    34961
# 12  UWA7648_CX29_A5_2_P16-1-J18    33102
# 13   UWA7648_CX29_A5_1_P2-1-P13    32695
# 14    UWA7648_CX29_A5_1_P1-1-I5    31763
# 15    UWA7648_CX29_A5_1_P8-1-A7    29530
# 16               Total Reads PF   671396
#                         SampleID  # Reads
# 0     UWA7648_CX13_A24_1_P1-1-I3    28422
# 1     UWA7648_CX13_A24_1_P4-1-C7    27646
# 2     UWA7648_CX13_A24_1_P6-1-M9    26075
# 3   UWA7648_CX13_A24_2_P11-1-K20    24981
# 4   UWA7648_CX13_A24_2_P13-1-I24    24621
# 5   UWA7648_CX13_A24_1_P10-1-K18    24141
# 6    UWA7648_CX13_A24_2_P16-1-J7    23704
# 7     UWA7648_CX13_A24_1_P5-1-K9    23340
# 8    UWA7648_CX13_A24_2_P15-1-L3    23033
# 9    UWA7648_CX13_A24_1_P7-1-A11    21920
# 10   UWA7648_CX13_A24_1_P9-1-M14    20745
# 11    UWA7648_CX13_A24_1_P3-1-O5    20503
# 12  UWA7648_CX13_A24_2_P12-1-E22    20428
# 13   UWA7648_CX13_A24_1_P8-1-I15    19772
# 14    UWA7648_CX13_A24_1_P2-1-E5    18255
# 15   UWA7648_CX13_A24_2_P14-1-J3    13744
# 16                Total Reads PF   361330

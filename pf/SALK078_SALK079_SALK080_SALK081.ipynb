# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240603_M00412_0820_000000000-GLF7P'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240603_M00412_0820_000000000-GLF7P_240603132817261312825 SALK078
#                        SampleID  # Reads
# 0    UCI4723_CX06_A9_1_P16-1-D8    48195
# 1    UCI4723_CX06_A9_1_P15-1-H6    39609
# 2    UCI4723_CX06_A9_1_P7-1-C10    39574
# 3     UCI4723_CX06_A9_1_P6-1-I2    37774
# 4    UCI4723_CX06_A9_1_P8-1-G10    37622
# 5   UCI4723_CX06_A9_1_P10-1-J11    36407
# 6    UCI4723_CX06_A9_1_P14-1-F6    34841
# 7    UCI4723_CX06_A9_1_P1-1-K15    33809
# 8    UCI4723_CX06_A9_1_P13-1-D6    33553
# 9    UCI4723_CX06_A9_1_P4-1-O21    33543
# 10   UCI4723_CX06_A9_1_P2-1-M17    33416
# 11   UCI4723_CX06_A9_1_P12-1-B6    33169
# 12   UCI4723_CX06_A9_1_P5-1-C23    32564
# 13   UCI4723_CX06_A9_1_P11-1-J2    31611
# 14   UCI4723_CX06_A9_1_P9-1-B11    31504
# 15   UCI4723_CX06_A9_1_P3-1-C21    31059
# 16               Total Reads PF   568250
# /gale/netapp/seq2/illumina_runs/240603_M00412_0820_000000000-GLF7P_240603141548705527967 SALK079
#                           SampleID  # Reads
# 0     UCI4723_CX1213_CaH_1_P6-1-G5    61541
# 1   UCI4723_CX1213_CaH_1_P11-1-F21    49865
# 2    UCI4723_CX1213_CaH_1_P7-1-N22    49729
# 3    UCI4723_CX1213_CaH_1_P9-1-F19    49080
# 4    UCI4723_CX1213_CaH_1_P5-1-P21    48865
# 5   UCI4723_CX1213_CaH_1_P14-1-K11    48631
# 6    UCI4723_CX1213_CaH_1_P13-1-E8    48523
# 7   UCI4723_CX1213_CaH_1_P12-1-P11    47101
# 8   UCI4723_CX1213_CaH_1_P15-1-K21    45243
# 9    UCI4723_CX1213_CaH_1_P8-1-F12    44647
# 10  UCI4723_CX1213_CaH_1_P16-1-C18    42799
# 11   UCI4723_CX1213_CaH_1_P4-1-B23    40864
# 12    UCI4723_CX1213_CaH_1_P3-1-F8    40182
# 13    UCI4723_CX1213_CaH_1_P2-1-A6    39403
# 14   UCI4723_CX1213_CaH_1_P1-1-J12    39237
# 15  UCI4723_CX1213_CaH_1_P10-1-E21    38200
# 16                  Total Reads PF   733910
# /gale/netapp/seq2/illumina_runs/240603_M00412_0820_000000000-GLF7P_240603141638181798123 SALK080
#                         SampleID  # Reads
# 0    UCI4723_CX13_A44_1_P15-1-O4    81817
# 1    UCI4723_CX13_A44_1_P6-1-A22    81266
# 2   UCI4723_CX13_A44_1_P16-1-J18    81000
# 3   UCI4723_CX13_A44_1_P10-1-I17    80348
# 4    UCI4723_CX13_A44_1_P7-1-B19    79775
# 5     UCI4723_CX13_A44_1_P3-1-F3    75665
# 6     UCI4723_CX13_A44_1_P8-1-A7    71223
# 7    UCI4723_CX13_A44_1_P14-1-P6    70326
# 8    UCI4723_CX13_A44_1_P12-1-N8    70179
# 9     UCI4723_CX13_A44_1_P1-1-I5    69120
# 10   UCI4723_CX13_A44_1_P5-1-G17    68824
# 11  UCI4723_CX13_A44_1_P13-1-J24    68338
# 12    UCI4723_CX13_A44_1_P9-1-G9    67734
# 13   UCI4723_CX13_A44_1_P2-1-P13    65601
# 14   UCI4723_CX13_A44_1_P11-1-E9    65098
# 15    UCI4723_CX13_A44_1_P4-1-E6    63552
# 16                Total Reads PF  1159866
# /gale/netapp/seq2/illumina_runs/240603_M00412_0820_000000000-GLF7P_240603141739671676157 SALK081
#                           SampleID  # Reads
# 0     UCI4723_CX1518_Idg_1_P6-1-M9   101533
# 1    UCI4723_CX1518_Idg_1_P15-1-L3    88641
# 2    UCI4723_CX1518_Idg_1_P14-1-J3    85604
# 3     UCI4723_CX1518_Idg_1_P5-1-K9    81634
# 4    UCI4723_CX1518_Idg_1_P16-1-J7    74625
# 5    UCI4723_CX1518_Idg_1_P7-1-A11    71995
# 6     UCI4723_CX1518_Idg_1_P3-1-O5    67012
# 7     UCI4723_CX1518_Idg_1_P4-1-C7    65801
# 8     UCI4723_CX1518_Idg_1_P1-1-I3    62206
# 9    UCI4723_CX1518_Idg_1_P8-1-I15    58487
# 10  UCI4723_CX1518_Idg_1_P10-1-K18    48694
# 11    UCI4723_CX1518_Idg_1_P2-1-E5    47086
# 12   UCI4723_CX1518_Idg_1_P9-1-M14    44380
# 13  UCI4723_CX1518_Idg_1_P13-1-I24    44089
# 14  UCI4723_CX1518_Idg_1_P12-1-E22    42484
# 15  UCI4723_CX1518_Idg_1_P11-1-K20    36955
# 16                  Total Reads PF  1021226
#       Pool  Total Reads
# 0  SALK078       568250
# 1  SALK079       733910
# 2  SALK080      1159866
# 3  SALK081      1021226

# %%
import pf
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("240329_M00412_0797_000000000-GK2D9_240331140346096455736", "SALK55"),
    ("240329_M00412_0797_000000000-GK2D9_240331140350864443676", "SALK56"),
    ("/gale/raidix/rdx-2/illumina_runs/240329_M00412_0797_000000000-GK2D9_240402121205207151519", "SALK57")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                          SampleID  # Reads
# 0    UWA7648_CX26_THM5_1_P8-1-I15    89973
# 1     UWA7648_CX26_THM5_1_P5-1-K9    79323
# 2    UWA7648_CX26_THM5_1_P7-1-A11    78765
# 3   UWA7648_CX26_THM5_2_P11-1-K20    78426
# 4   UWA7648_CX26_THM5_1_P10-1-K18    78419
# 5   UWA7648_CX26_THM5_2_P13-1-I24    76222
# 6    UWA7648_CX26_THM5_2_P16-1-J7    74787
# 7     UWA7648_CX26_THM5_1_P1-1-I3    74167
# 8    UWA7648_CX26_THM5_2_P15-1-L3    72401
# 9   UWA7648_CX26_THM5_2_P12-1-E22    71554
# 10    UWA7648_CX26_THM5_1_P3-1-O5    71034
# 11    UWA7648_CX26_THM5_1_P2-1-E5    70855
# 12    UWA7648_CX26_THM5_1_P6-1-M9    70841
# 13    UWA7648_CX26_THM5_1_P4-1-C7    69504
# 14   UWA7648_CX26_THM5_2_P14-1-J3    69066
# 15   UWA7648_CX26_THM5_1_P9-1-M14    59303
# 16                 Total Reads PF  1184640
#                            SampleID  # Reads
# 0    UWA7648_CX2021_HTH1_1_P5-1-C23    47961
# 1    UWA7648_CX2021_HTH1_1_P16-1-D8    47053
# 2     UWA7648_CX2021_HTH1_1_P6-1-I2    45547
# ...

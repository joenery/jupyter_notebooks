# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("240424_M00412_0804_000000000-GK84C_240425114841009034171", "SALK61"),
    ("240424_M00412_0804_000000000-GK84C_240425114936584195127", "SALK62"),
    ("240424_M00412_0804_000000000-GK84C_240425115014561027949", "SALK063")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                          SampleID  # Reads
# 0    UWA7648_BS01_MGM2_1_P15-1-O4    14130
# 1    UWA7648_BS01_MGM2_1_P6-1-A22    14124
# 2    UWA7648_BS01_MGM2_1_P2-1-P13    13038
# 3     UWA7648_BS01_MGM2_1_P8-1-A7    12407
# 4     UWA7648_BS01_MGM2_1_P3-1-F3    12289
# 5     UWA7648_BS01_MGM2_1_P4-1-E6    12203
# 6   UWA7648_BS01_MGM2_1_P16-1-J18    11638
# 7    UWA7648_BS01_MGM2_1_P7-1-B19    11540
# 8    UWA7648_BS01_MGM2_1_P11-1-E9    10874
# 9   UWA7648_BS01_MGM2_1_P13-1-J24    10411
# 10    UWA7648_BS01_MGM2_1_P1-1-I5    10241
# 11   UWA7648_BS01_MGM2_1_P5-1-G17    10109
# 12  UWA7648_BS01_MGM2_1_P10-1-I17     9967
# 13   UWA7648_BS01_MGM2_1_P14-1-P6     9786
# 14    UWA7648_BS01_MGM2_1_P9-1-G9     9506
# 15   UWA7648_BS01_MGM2_1_P12-1-N8     8864
# 16                 Total Reads PF   181127
#                             SampleID  # Reads
# 0     UWA7648_CX2324_SubTH_1_P5-1-K9   189675
# 1   UWA7648_CX2324_SubTH_1_P11-1-K20   178451
# 2     UWA7648_CX2324_SubTH_1_P3-1-O5   177318
# 3     UWA7648_CX2324_SubTH_1_P6-1-M9   174558
# 4    UWA7648_CX2324_SubTH_1_P8-1-I15   171051
# 5    UWA7648_CX2324_SubTH_1_P7-1-A11   170253
# 6     UWA7648_CX2324_SubTH_1_P1-1-I3   170216
# 7     UWA7648_CX2324_SubTH_1_P4-1-C7   169273
# 8        UWA7648_BS02_MGM3_1_P5-1-J7   167949
# 9        UWA7648_BS02_MGM3_1_P3-1-J3   161171
# 10      UWA7648_BS02_MGM3_1_P2-1-I24   158441
# 11  UWA7648_CX2324_SubTH_1_P10-1-K18   154911
# 12    UWA7648_CX2324_SubTH_1_P2-1-E5   154110
# 13      UWA7648_BS02_MGM3_1_P1-1-E22   150370
# 14   UWA7648_CX2324_SubTH_1_P9-1-M14   149987
# 15       UWA7648_BS02_MGM3_1_P4-1-L3   148876
# 16                    Total Reads PF  2646610
#                              SampleID  # Reads
# 0    UWA7648_BS030405_PnTg_1_P7-1-C10   129685
# 1    UWA7648_BS030405_PnTg_1_P5-1-C23    96822
# 2    UWA7648_BS030405_PnTg_1_P16-1-D8    92675
# 3    UWA7648_BS030405_PnTg_1_P1-1-K15    89719
# 4    UWA7648_BS030405_PnTg_1_P4-1-O21    86872
# 5     UWA7648_BS030405_PnTg_1_P6-1-I2    86082
# 6    UWA7648_BS030405_PnTg_1_P3-1-C21    84446
# 7    UWA7648_BS030405_PnTg_1_P2-1-M17    82734
# 8    UWA7648_BS030405_PnTg_1_P8-1-G10    79658
# 9    UWA7648_BS030405_PnTg_1_P15-1-H6    75819
# 10   UWA7648_BS030405_PnTg_1_P14-1-F6    73275
# 11  UWA7648_BS030405_PnTg_1_P10-1-J11    72793
# 12   UWA7648_BS030405_PnTg_1_P13-1-D6    67024
# 13   UWA7648_BS030405_PnTg_1_P9-1-B11    65937
# 14   UWA7648_BS030405_PnTg_1_P12-1-B6    65239
# 15   UWA7648_BS030405_PnTg_1_P11-1-J2    63221
# 16                     Total Reads PF  1312001

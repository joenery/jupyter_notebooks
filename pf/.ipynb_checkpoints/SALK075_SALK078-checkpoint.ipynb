# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240529_M00412_0819_000000000-GK8W2_240529152549774665245 SALK075
#                         SampleID  # Reads
# 0    UCI4723_CX04_A32_1_P5-1-P21    30304
# 1    UCI4723_CX04_A32_1_P7-1-N22    30238
# 2    UCI4723_CX04_A32_1_P1-1-J12    28256
# 3    UCI4723_CX04_A32_1_P4-1-B23    27518
# 4    UCI4723_CX04_A32_1_P9-1-F19    27186
# 5     UCI4723_CX04_A32_1_P2-1-A6    26276
# 6     UCI4723_CX04_A32_1_P6-1-G5    25658
# 7   UCI4723_CX04_A32_1_P10-1-E21    25092
# 8     UCI4723_CX04_A32_1_P3-1-F8    25033
# 9    UCI4723_CX04_A32_1_P8-1-F12    25019
# 10  UCI4723_CX04_A32_1_P11-1-F21    24679
# 11   UCI4723_CX04_A32_1_P13-1-E8    24023
# 12  UCI4723_CX04_A32_1_P16-1-C18    23436
# 13  UCI4723_CX04_A32_1_P14-1-K11    22666
# 14  UCI4723_CX04_A32_1_P15-1-K21    22045
# 15  UCI4723_CX04_A32_1_P12-1-P11    21826
# 16                Total Reads PF   409255
# /gale/netapp/seq2/illumina_runs/240529_M00412_0819_000000000-GK8W2_240529152721671703584 SALK076
#                         SampleID  # Reads
# 0    UCI4723_CX11_A45_1_P15-1-O4    59655
# 1   UCI4723_CX11_A45_1_P16-1-J18    58900
# 2   UCI4723_CX11_A45_1_P10-1-I17    58661
# 3     UCI4723_CX11_A45_1_P3-1-F3    56750
# 4    UCI4723_CX11_A45_1_P6-1-A22    52845
# 5    UCI4723_CX11_A45_1_P7-1-B19    51534
# 6    UCI4723_CX11_A45_1_P2-1-P13    50699
# 7   UCI4723_CX11_A45_1_P13-1-J24    50330
# 8     UCI4723_CX11_A45_1_P1-1-I5    47505
# 9    UCI4723_CX11_A45_1_P11-1-E9    47427
# 10    UCI4723_CX11_A45_1_P9-1-G9    47329
# 11   UCI4723_CX11_A45_1_P14-1-P6    47237
# 12    UCI4723_CX11_A45_1_P8-1-A7    46961
# 13   UCI4723_CX11_A45_1_P5-1-G17    45859
# 14    UCI4723_CX11_A45_1_P4-1-E6    43712
# 15   UCI4723_CX11_A45_1_P12-1-N8    42302
# 16                Total Reads PF   807706
# /gale/netapp/seq2/illumina_runs/240529_M00412_0819_000000000-GK8W2_240529152851267008413 SALK077
#                         SampleID  # Reads
# 0    UCI4723_CX07_A46_1_P9-1-M14   104827
# 1   UCI4723_CX07_A46_1_P11-1-K20    98212
# 2    UCI4723_CX07_A46_1_P8-1-I15    95578
# 3   UCI4723_CX07_A46_1_P10-1-K18    95212
# 4    UCI4723_CX07_A46_1_P7-1-A11    94909
# 5    UCI4723_CX07_A46_1_P16-1-J7    94603
# 6     UCI4723_CX07_A46_1_P6-1-M9    92858
# 7   UCI4723_CX07_A46_1_P13-1-I24    88373
# 8     UCI4723_CX07_A46_1_P4-1-C7    88255
# 9    UCI4723_CX07_A46_1_P14-1-J3    86885
# 10    UCI4723_CX07_A46_1_P5-1-K9    86010
# 11   UCI4723_CX07_A46_1_P15-1-L3    85016
# 12  UCI4723_CX07_A46_1_P12-1-E22    83988
# 13    UCI4723_CX07_A46_1_P1-1-I3    81793
# 14    UCI4723_CX07_A46_1_P3-1-O5    78622
# 15    UCI4723_CX07_A46_1_P2-1-E5    76252
# 16                Total Reads PF  1431393
# /gale/netapp/seq2/illumina_runs/240529_M00412_0819_000000000-GK8W2_240530081953466291204 SALK074
#                         SampleID  # Reads
# 0    UCI4723_CX01_A10_1_P7-1-C10    74522
# 1    UCI4723_CX01_A10_1_P5-1-C23    72811
# 2    UCI4723_CX01_A10_1_P16-1-D8    72209
# 3    UCI4723_CX01_A10_1_P2-1-M17    72054
# 4    UCI4723_CX01_A10_1_P15-1-H6    71446
# 5    UCI4723_CX01_A10_1_P9-1-B11    71439
# 6    UCI4723_CX01_A10_1_P8-1-G10    70289
# 7     UCI4723_CX01_A10_1_P6-1-I2    68531
# 8    UCI4723_CX01_A10_1_P1-1-K15    66837
# 9    UCI4723_CX01_A10_1_P4-1-O21    66175
# 10   UCI4723_CX01_A10_1_P3-1-C21    64044
# 11  UCI4723_CX01_A10_1_P10-1-J11    63850
# 12   UCI4723_CX01_A10_1_P14-1-F6    63798
# 13   UCI4723_CX01_A10_1_P11-1-J2    63768
# 14   UCI4723_CX01_A10_1_P12-1-B6    61074
# 15   UCI4723_CX01_A10_1_P13-1-D6    61066
# 16                Total Reads PF  1083913
#       Pool  Total Reads
# 0  SALK075       409255
# 1  SALK076       807706
# 2  SALK077      1431393
# 3  SALK074      1083913

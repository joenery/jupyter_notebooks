# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("240315_M00412_0795_000000000-GJNFM_240316194428709278292", "SALK50"),
    ("240315_M00412_0795_000000000-GJNFM_240316194430907811583", "SALK51"),
    ("240315_M00412_0795_000000000-GJNFM_240316194426524090774", "Remind2")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                          SampleID  # Reads
# 0    UWA7648_CX20_BNST_1_P1-1-J12   112461
# 1     UWA7648_CX20_BNST_1_P2-1-A6   112203
# 2    UWA7648_CX20_BNST_1_P7-1-N22   110787
# 3    UWA7648_CX20_BNST_1_P5-1-P21   106116
# 4    UWA7648_CX20_BNST_1_P9-1-F19    98239
# 5   UWA7648_CX20_BNST_2_P14-1-K11    96785
# 6   UWA7648_CX20_BNST_2_P15-1-K21    96778
# 7   UWA7648_CX20_BNST_1_P10-1-E21    94640
# 8     UWA7648_CX20_BNST_1_P6-1-G5    93221
# 9    UWA7648_CX20_BNST_2_P13-1-E8    91332
# 10  UWA7648_CX20_BNST_1_P12-1-P11    91127
# 11   UWA7648_CX20_BNST_1_P4-1-B23    90508
# 12    UWA7648_CX20_BNST_1_P3-1-F8    89512
# 13  UWA7648_CX20_BNST_1_P11-1-F21    87930
# 14  UWA7648_CX20_BNST_2_P16-1-C18    84256
# 15   UWA7648_CX20_BNST_1_P8-1-F12    60823
# 16                 Total Reads PF  1516718
#                            SampleID  # Reads
# 0    UWA7648_CX202223_GP_1_P15-1-O4   104335
# 1   UWA7648_CX202223_GP_1_P10-1-I17   102711
# 2    UWA7648_CX202223_GP_1_P11-1-E9   100816
# ...

# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart, generate_read_adj_table
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240715_M00412_0835_000000000-GLF76'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
summary_df
# Out:
# /gale/netapp/seq2/illumina_runs/240715_M00412_0835_000000000-GLF76_240716085718924205831 SALK114
#                              SampleID  # Reads
# 0    UCI4723_CX181921_HIPu_1_P14-1-F6   103008
# 1    UCI4723_CX181921_HIPu_1_P11-1-J2    97077
# 2    UCI4723_CX181921_HIPu_1_P15-1-H6    93606
# 3    UCI4723_CX181921_HIPu_1_P7-1-C10    91192
# 4    UCI4723_CX181921_HIPu_1_P16-1-D8    79726
# 5     UCI4723_CX181921_HIPu_1_P6-1-I2    78492
# 6    UCI4723_CX181921_HIPu_1_P13-1-D6    76821
# 7    UCI4723_CX181921_HIPu_1_P8-1-G10    73469
# 8    UCI4723_CX181921_HIPu_1_P9-1-B11    68893
# 9    UCI4723_CX181921_HIPu_1_P12-1-B6    68371
# 10   UCI4723_CX181921_HIPu_1_P1-1-K15    63808
# 11   UCI4723_CX181921_HIPu_1_P4-1-O21    60572
# 12   UCI4723_CX181921_HIPu_1_P2-1-M17    57652
# 13   UCI4723_CX181921_HIPu_1_P3-1-C21    53671
# 14  UCI4723_CX181921_HIPu_1_P10-1-J11    49010
# 15   UCI4723_CX181921_HIPu_1_P5-1-C23    45980
# 16                     Total Reads PF  1161348
# /gale/netapp/seq2/illumina_runs/240715_M00412_0835_000000000-GLF76_240716085730183682279 SALK113
#                           SampleID  # Reads
# 0     UCI4723_CX3536_Pro_1_P5-1-K9    84646
# 1     UCI4723_CX3536_Pro_1_P3-1-O5    82192
# 2     UCI4723_CX3536_Pro_1_P6-1-M9    77844
# 3   UCI4723_CX3536_Pro_1_P11-1-K20    76606
# 4    UCI4723_CX3536_Pro_1_P8-1-I15    76258
# 5     UCI4723_CX3536_Pro_1_P4-1-C7    75415
# 6    UCI4723_CX3536_Pro_1_P9-1-M14    74632
# 7     UCI4723_CX3536_Pro_1_P2-1-E5    74388
# 8    UCI4723_CX3536_Pro_1_P7-1-A11    73518
# 9    UCI4723_CX3536_Pro_1_P16-1-J7    71363
# 10  UCI4723_CX3536_Pro_1_P12-1-E22    70742
# 11    UCI4723_CX3536_Pro_1_P1-1-I3    67736
# 12  UCI4723_CX3536_Pro_1_P10-1-K18    67069
# 13   UCI4723_CX3536_Pro_1_P15-1-L3    66472
# 14  UCI4723_CX3536_Pro_1_P13-1-I24    63988
# 15   UCI4723_CX3536_Pro_1_P14-1-J3    61669
# 16                  Total Reads PF  1164538
# /gale/netapp/seq2/illumina_runs/240715_M00412_0835_000000000-GLF76_240716085739907587656 SALK112
#                        SampleID  # Reads
# 0    UCI4723_CX34_A7_1_P6-1-A22    81879
# 1   UCI4723_CX34_A7_1_P13-1-J24    78390
# 2    UCI4723_CX34_A7_1_P2-1-P13    78193
# 3    UCI4723_CX34_A7_1_P14-1-P6    71640
# 4     UCI4723_CX34_A7_1_P3-1-F3    70963
# 5    UCI4723_CX34_A7_1_P11-1-E9    68376
# 6   UCI4723_CX34_A7_1_P10-1-I17    66159
# 7     UCI4723_CX34_A7_1_P4-1-E6    66004
# 8    UCI4723_CX34_A7_1_P5-1-G17    65229
# 9    UCI4723_CX34_A7_1_P12-1-N8    62901
# 10    UCI4723_CX34_A7_1_P1-1-I5    60501
# 11    UCI4723_CX34_A7_1_P9-1-G9    51727
# 12   UCI4723_CX34_A7_1_P15-1-O4    35616
# 13   UCI4723_CX34_A7_1_P7-1-B19    28126
# 14  UCI4723_CX34_A7_1_P16-1-J18    17119
# 15    UCI4723_CX34_A7_1_P8-1-A7    11003
# 16               Total Reads PF   913826
# /gale/netapp/seq2/illumina_runs/240715_M00412_0835_000000000-GLF76_240716085749552387698 SALK111
#                            SampleID  # Reads
# 0     UCI4723_CX2728_HIPc_1_P3-1-F8   119461
# 1   UCI4723_CX2728_HIPc_1_P11-1-F21   111999
# 2    UCI4723_CX2728_HIPc_1_P4-1-B23   104843
# 3    UCI4723_CX2728_HIPc_1_P5-1-P21   101038
# 4    UCI4723_CX2728_HIPc_1_P7-1-N22    99420
# 5     UCI4723_CX2728_HIPc_1_P2-1-A6    97330
# 6     UCI4723_CX2728_HIPc_1_P6-1-G5    95455
# 7   UCI4723_CX2728_HIPc_1_P16-1-C18    82501
# 8   UCI4723_CX2728_HIPc_1_P10-1-E21    80943
# 9   UCI4723_CX2728_HIPc_1_P14-1-K11    77021
# 10  UCI4723_CX2728_HIPc_1_P12-1-P11    73961
# 11  UCI4723_CX2728_HIPc_1_P15-1-K21    73628
# 12   UCI4723_CX2728_HIPc_1_P13-1-E8    72159
# 13   UCI4723_CX2728_HIPc_1_P8-1-F12    71701
# 14   UCI4723_CX2728_HIPc_1_P1-1-J12    69608
# 15   UCI4723_CX2728_HIPc_1_P9-1-F19    46361
# 16                   Total Reads PF  1377429
#       Pool  Total Reads
# 0  SALK114      1161348
# 1  SALK113      1164538
# 2  SALK112       913826
# 3  SALK111      1377429

# %%
generate_read_adj_table(summary_df)
# Out:
#         Pool Combo     Pool  Total Reads  Read adj factor
# 0  SALK112_SALK111  SALK112       913826         1.507321
# 1  SALK112_SALK111  SALK111      1377429         0.663429
# 2  SALK114_SALK113  SALK114      1161348         1.002747
# 3  SALK114_SALK113  SALK113      1164538         0.997261

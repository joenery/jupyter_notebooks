# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart, generate_read_adj_table
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240711_M00412_0833_000000000-GLCN9'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
summary_df
# Out:
# /gale/netapp/seq2/illumina_runs/240711_M00412_0833_000000000-GLCN9_240711164023158182827 SALK106
#                            SampleID  # Reads
# 0    UCI4723_CX1718_AMY2_1_P1-1-K15    46687
# 1    UCI4723_CX1718_AMY2_1_P16-1-D8    45926
# 2     UCI4723_CX1718_AMY2_1_P6-1-I2    43271
# 3    UCI4723_CX1718_AMY2_1_P12-1-B6    42363
# 4    UCI4723_CX1718_AMY2_1_P7-1-C10    42197
# 5    UCI4723_CX1718_AMY2_1_P2-1-M17    41327
# 6    UCI4723_CX1718_AMY2_1_P8-1-G10    41109
# 7    UCI4723_CX1718_AMY2_1_P9-1-B11    40087
# 8    UCI4723_CX1718_AMY2_1_P13-1-D6    39576
# 9    UCI4723_CX1718_AMY2_1_P3-1-C21    38774
# 10   UCI4723_CX1718_AMY2_1_P14-1-F6    37111
# 11   UCI4723_CX1718_AMY2_1_P4-1-O21    36764
# 12  UCI4723_CX1718_AMY2_1_P10-1-J11    36414
# 13   UCI4723_CX1718_AMY2_1_P5-1-C23    35240
# 14   UCI4723_CX1718_AMY2_1_P15-1-H6    31958
# 15   UCI4723_CX1718_AMY2_1_P11-1-J2    29003
# 16                   Total Reads PF   627807
# /gale/netapp/seq2/illumina_runs/240711_M00412_0833_000000000-GLCN9_240711164033918186685 SALK107
#                          SampleID  # Reads
# 0    UCI4723_CX3842_V2_1_P7-1-N22    33397
# 1   UCI4723_CX3842_V2_1_P14-1-K11    31666
# 2    UCI4723_CX3842_V2_1_P4-1-B23    28633
# 3     UCI4723_CX3842_V2_1_P6-1-G5    28232
# 4   UCI4723_CX3842_V2_1_P16-1-C18    27907
# 5    UCI4723_CX3842_V2_1_P5-1-P21    27799
# 6    UCI4723_CX3842_V2_1_P1-1-J12    27775
# 7   UCI4723_CX3842_V2_1_P11-1-F21    27651
# 8   UCI4723_CX3842_V2_1_P12-1-P11    27635
# 9    UCI4723_CX3842_V2_1_P13-1-E8    27340
# 10   UCI4723_CX3842_V2_1_P8-1-F12    26325
# 11    UCI4723_CX3842_V2_1_P3-1-F8    24219
# 12  UCI4723_CX3842_V2_1_P10-1-E21    24165
# 13  UCI4723_CX3842_V2_1_P15-1-K21    21662
# 14   UCI4723_CX3842_V2_1_P9-1-F19    19563
# 15    UCI4723_CX3842_V2_1_P2-1-A6    15563
# 16                 Total Reads PF   419532
# /gale/netapp/seq2/illumina_runs/240711_M00412_0833_000000000-GLCN9_240711164043806877585 SALK108
#                         SampleID  # Reads
# 0    UCI4723_CX41_PSC_1_P2-1-P13    32327
# 1    UCI4723_CX41_PSC_1_P6-1-A22    28727
# 2    UCI4723_CX41_PSC_1_P15-1-O4    23441
# 3     UCI4723_CX41_PSC_1_P1-1-I5    23372
# 4     UCI4723_CX41_PSC_1_P3-1-F3    22158
# 5     UCI4723_CX41_PSC_1_P8-1-A7    21880
# 6    UCI4723_CX41_PSC_1_P5-1-G17    20926
# 7    UCI4723_CX41_PSC_1_P14-1-P6    20152
# 8     UCI4723_CX41_PSC_1_P4-1-E6    20050
# 9   UCI4723_CX41_PSC_1_P16-1-J18    19927
# 10  UCI4723_CX41_PSC_1_P13-1-J24    17540
# 11   UCI4723_CX41_PSC_1_P7-1-B19    17249
# 12  UCI4723_CX41_PSC_1_P10-1-I17    17154
# 13   UCI4723_CX41_PSC_1_P11-1-E9    16682
# 14    UCI4723_CX41_PSC_1_P9-1-G9    16597
# 15   UCI4723_CX41_PSC_1_P12-1-N8    15707
# 16                Total Reads PF   333889
# /gale/netapp/seq2/illumina_runs/240711_M00412_0833_000000000-GLCN9_240711164053594791286 SALK109
#                         SampleID  # Reads
# 0     UCI4723_CX40_V1C_1_P6-1-M9    28077
# 1    UCI4723_CX40_V1C_1_P15-1-L3    27992
# 2    UCI4723_CX40_V1C_1_P16-1-J7    24582
# 3    UCI4723_CX40_V1C_1_P7-1-A11    24506
# 4     UCI4723_CX40_V1C_1_P3-1-O5    24397
# 5     UCI4723_CX40_V1C_1_P5-1-K9    24304
# 6    UCI4723_CX40_V1C_1_P8-1-I15    23762
# 7   UCI4723_CX40_V1C_1_P11-1-K20    23715
# 8     UCI4723_CX40_V1C_1_P4-1-C7    23448
# 9     UCI4723_CX40_V1C_1_P1-1-I3    22811
# 10   UCI4723_CX40_V1C_1_P14-1-J3    22441
# 11  UCI4723_CX40_V1C_1_P10-1-K18    21567
# 12  UCI4723_CX40_V1C_1_P12-1-E22    21383
# 13  UCI4723_CX40_V1C_1_P13-1-I24    21007
# 14    UCI4723_CX40_V1C_1_P2-1-E5    20607
# 15   UCI4723_CX40_V1C_1_P9-1-M14    19382
# 16                Total Reads PF   373981
#       Pool  Total Reads
# 0  SALK106       627807
# 1  SALK107       419532
# 2  SALK108       333889
# 3  SALK109       373981

# %%
generate_read_adj_table(summary_df)
# Out:
#         Pool Combo     Pool  Total Reads  Read adj factor
# 0  SALK106_SALK107  SALK106       627807         0.668250
# 1  SALK106_SALK107  SALK107       419532         1.496446
# 2  SALK108_SALK109  SALK108       333889         1.120076
# 3  SALK108_SALK109  SALK109       373981         0.892797

# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240516_M00412_0815_000000000-GJMV9'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    generate_reads_pf_chart(run_folder, pool)
# Out:
# /gale/netapp/seq2/illumina_runs/240516_M00412_0815_000000000-GJMV9_240517075757701318199 SALK068
#                               SampleID  # Reads
# 0    UWA7648_CB60_Human_VeF_1_P15-1-O4    69780
# 1    UWA7648_CB60_Human_VeF_1_P14-1-P6    67516
# 2   UWA7648_CB60_Human_VeF_1_P16-1-J18    67376
# 3   UWA7648_CB60_Human_VeF_1_P13-1-J24    67220
# 4    UWA7648_CB60_Human_VeF_1_P11-1-E9    63109
# 5    UWA7648_CB60_Human_VeF_1_P6-1-A22    62225
# 6    UWA7648_CB60_Human_VeF_1_P7-1-B19    60917
# 7     UWA7648_CB60_Human_VeF_1_P3-1-F3    60798
# 8   UWA7648_CB60_Human_VeF_1_P10-1-I17    60796
# 9    UWA7648_CB60_Human_VeF_1_P12-1-N8    59477
# 10   UWA7648_CB60_Human_VeF_1_P2-1-P13    57216
# 11   UWA7648_CB60_Human_VeF_1_P5-1-G17    56981
# 12    UWA7648_CB60_Human_VeF_1_P4-1-E6    56007
# 13    UWA7648_CB60_Human_VeF_1_P1-1-I5    53705
# 14    UWA7648_CB60_Human_VeF_1_P8-1-A7    51273
# 15    UWA7648_CB60_Human_VeF_1_P9-1-G9    44125
# 16                      Total Reads PF   958521
# /gale/netapp/seq2/illumina_runs/240516_M00412_0815_000000000-GJMV9_240517080005340183635 SALK069
#                                SampleID  # Reads
# 0   UWA7648_CB60_Human_VePo_1_P11-1-K20    69348
# 1     UWA7648_CB60_Human_VePo_1_P5-1-K9    66912
# 2    UWA7648_CB60_Human_VePo_1_P16-1-J7    66658
# 3    UWA7648_CB60_Human_VePo_1_P7-1-A11    63826
# 4    UWA7648_CB60_Human_VePo_1_P9-1-M14    63519
# 5     UWA7648_CB60_Human_VePo_1_P6-1-M9    63373
# 6     UWA7648_CB60_Human_VePo_1_P4-1-C7    61516
# 7    UWA7648_CB60_Human_VePo_1_P15-1-L3    60883
# 8   UWA7648_CB60_Human_VePo_1_P12-1-E22    60242
# 9   UWA7648_CB60_Human_VePo_1_P10-1-K18    59307
# 10   UWA7648_CB60_Human_VePo_1_P14-1-J3    59000
# 11   UWA7648_CB60_Human_VePo_1_P8-1-I15    58949
# 12    UWA7648_CB60_Human_VePo_1_P3-1-O5    57814
# 13  UWA7648_CB60_Human_VePo_1_P13-1-I24    57150
# 14    UWA7648_CB60_Human_VePo_1_P1-1-I3    56242
# 15    UWA7648_CB60_Human_VePo_1_P2-1-E5    53113
# 16                       Total Reads PF   977852
# /gale/netapp/seq2/illumina_runs/240516_M00412_0815_000000000-GJMV9_240517080211664657783 SALK070
#                                SampleID  # Reads
# 0    UWA7648_CB67_Human_CBLA_1_P16-1-D8    78965
# 1    UWA7648_CB67_Human_CBLA_1_P14-1-F6    59559
# 2    UWA7648_CB67_Human_CBLA_1_P15-1-H6    58296
# 3     UWA7648_CB67_Human_CBLA_1_P6-1-I2    51682
# 4    UWA7648_CB67_Human_CBLA_1_P5-1-C23    50871
# 5    UWA7648_CB67_Human_CBLA_1_P13-1-D6    50077
# 6    UWA7648_CB67_Human_CBLA_1_P7-1-C10    48839
# 7    UWA7648_CB67_Human_CBLA_1_P3-1-C21    47376
# 8    UWA7648_CB67_Human_CBLA_1_P4-1-O21    47248
# 9    UWA7648_CB67_Human_CBLA_1_P8-1-G10    46456
# 10   UWA7648_CB67_Human_CBLA_1_P2-1-M17    45652
# 11   UWA7648_CB67_Human_CBLA_1_P1-1-K15    45141
# 12   UWA7648_CB67_Human_CBLA_1_P11-1-J2    41986
# 13  UWA7648_CB67_Human_CBLA_1_P10-1-J11    41153
# 14   UWA7648_CB67_Human_CBLA_1_P12-1-B6    41068
# 15   UWA7648_CB67_Human_CBLA_1_P9-1-B11    36372
# 16                       Total Reads PF   790741
# /gale/netapp/seq2/illumina_runs/240516_M00412_0815_000000000-GJMV9_240517080714831956749 SALK071
#                                SampleID  # Reads
# 0    UWA7648_CB61626364_CbDN_1_P9-1-F19   110872
# 1    UWA7648_CB61626364_CbDN_1_P5-1-P21   108634
# 2    UWA7648_CB61626364_CbDN_1_P7-1-N22   103428
# 3    UWA7648_CB61626364_CbDN_1_P4-1-B23   100391
# 4   UWA7648_CB61626364_CbDN_1_P16-1-C18    96254
# 5   UWA7648_CB61626364_CbDN_1_P15-1-K21    95188
# 6   UWA7648_CB61626364_CbDN_1_P14-1-K11    94665
# 7   UWA7648_CB61626364_CbDN_1_P11-1-F21    91535
# 8   UWA7648_CB61626364_CbDN_1_P12-1-P11    91196
# 9    UWA7648_CB61626364_CbDN_1_P8-1-F12    88564
# 10   UWA7648_CB61626364_CbDN_1_P1-1-J12    88329
# 11    UWA7648_CB61626364_CbDN_1_P6-1-G5    87768
# 12   UWA7648_CB61626364_CbDN_1_P13-1-E8    87108
# 13    UWA7648_CB61626364_CbDN_1_P2-1-A6    86857
# 14  UWA7648_CB61626364_CbDN_1_P10-1-E21    84726
# 15    UWA7648_CB61626364_CbDN_1_P3-1-F8    82154
# 16                       Total Reads PF  1497669

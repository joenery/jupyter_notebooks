# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart, generate_read_adj_table
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240529_M00412_0819_000000000-GK8W2'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240709_M00412_0831_000000000-GLCR8'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
summary_df
# Out:
# /gale/netapp/seq2/illumina_runs/240709_M00412_0831_000000000-GLCR8_240710080639958409788 SALK102
#                           SampleID  # Reads
# 0    UCI4723_CX2122_A1C_1_P7-1-C10    55350
# 1    UCI4723_CX2122_A1C_1_P8-1-G10    51596
# 2    UCI4723_CX2122_A1C_1_P1-1-K15    43644
# 3    UCI4723_CX2122_A1C_1_P16-1-D8    41536
# 4    UCI4723_CX2122_A1C_1_P13-1-D6    40656
# 5    UCI4723_CX2122_A1C_1_P3-1-C21    40043
# 6    UCI4723_CX2122_A1C_1_P15-1-H6    39987
# 7    UCI4723_CX2122_A1C_1_P5-1-C23    37855
# 8    UCI4723_CX2122_A1C_1_P11-1-J2    37332
# 9    UCI4723_CX2122_A1C_1_P12-1-B6    37066
# 10   UCI4723_CX2122_A1C_1_P2-1-M17    36851
# 11   UCI4723_CX2122_A1C_1_P14-1-F6    36559
# 12   UCI4723_CX2122_A1C_1_P4-1-O21    36521
# 13   UCI4723_CX2122_A1C_1_P9-1-B11    35200
# 14  UCI4723_CX2122_A1C_1_P10-1-J11    33711
# 15    UCI4723_CX2122_A1C_1_P6-1-I2    30365
# 16                  Total Reads PF   634272
# /gale/netapp/seq2/illumina_runs/240709_M00412_0831_000000000-GLCR8_240710080752547578344 SALK103
#                            SampleID  # Reads
# 0   UCI4723_CX1718_AMY1_1_P10-1-E21   125813
# 1     UCI4723_CX1718_AMY1_1_P2-1-A6   110064
# 2    UCI4723_CX1718_AMY1_1_P7-1-N22   108366
# 3    UCI4723_CX1718_AMY1_1_P1-1-J12   102616
# 4    UCI4723_CX1718_AMY1_1_P8-1-F12   102182
# 5    UCI4723_CX1718_AMY1_1_P9-1-F19    99635
# 6    UCI4723_CX1718_AMY1_1_P4-1-B23    98840
# 7    UCI4723_CX1718_AMY1_1_P5-1-P21    96615
# 8    UCI4723_CX1718_AMY1_1_P13-1-E8    93315
# 9   UCI4723_CX1718_AMY1_1_P11-1-F21    93296
# 10  UCI4723_CX1718_AMY1_1_P12-1-P11    88969
# 11    UCI4723_CX1718_AMY1_1_P6-1-G5    87510
# 12  UCI4723_CX1718_AMY1_1_P16-1-C18    87324
# 13  UCI4723_CX1718_AMY1_1_P14-1-K11    84153
# 14    UCI4723_CX1718_AMY1_1_P3-1-F8    80007
# 15  UCI4723_CX1718_AMY1_1_P15-1-K21    66675
# 16                   Total Reads PF  1525380
# /gale/netapp/seq2/illumina_runs/240709_M00412_0831_000000000-GLCR8_240710080924869452549 SALK104
#                              SampleID  # Reads
# 0    UCI4723_CX252728_PPHC_1_P7-1-B19   102888
# 1    UCI4723_CX252728_PPHC_1_P6-1-A22    99022
# 2    UCI4723_CX252728_PPHC_1_P15-1-O4    98122
# 3     UCI4723_CX252728_PPHC_1_P8-1-A7    94178
# 4   UCI4723_CX252728_PPHC_1_P16-1-J18    93756
# 5    UCI4723_CX252728_PPHC_1_P2-1-P13    92393
# 6     UCI4723_CX252728_PPHC_1_P4-1-E6    90118
# 7     UCI4723_CX252728_PPHC_1_P3-1-F3    89227
# 8    UCI4723_CX252728_PPHC_1_P5-1-G17    86432
# 9   UCI4723_CX252728_PPHC_1_P10-1-I17    84109
# 10   UCI4723_CX252728_PPHC_1_P14-1-P6    84047
# 11    UCI4723_CX252728_PPHC_1_P1-1-I5    81895
# 12   UCI4723_CX252728_PPHC_1_P11-1-E9    81639
# 13    UCI4723_CX252728_PPHC_1_P9-1-G9    80237
# 14  UCI4723_CX252728_PPHC_1_P13-1-J24    79085
# 15   UCI4723_CX252728_PPHC_1_P12-1-N8    77176
# 16                     Total Reads PF  1414324
# /gale/netapp/seq2/illumina_runs/240709_M00412_0831_000000000-GLCR8_240710081005650967101 SALK105
#                           SampleID  # Reads
# 0    UCI4723_CX1718_LEC_1_P8-1-I15    66328
# 1   UCI4723_CX1718_LEC_1_P10-1-K18    63860
# 2     UCI4723_CX1718_LEC_1_P6-1-M9    62204
# 3    UCI4723_CX1718_LEC_1_P16-1-J7    61486
# 4    UCI4723_CX1718_LEC_1_P9-1-M14    60969
# 5     UCI4723_CX1718_LEC_1_P5-1-K9    60943
# 6    UCI4723_CX1718_LEC_1_P7-1-A11    60200
# 7   UCI4723_CX1718_LEC_1_P12-1-E22    57778
# 8   UCI4723_CX1718_LEC_1_P11-1-K20    57739
# 9     UCI4723_CX1718_LEC_1_P4-1-C7    57383
# 10    UCI4723_CX1718_LEC_1_P3-1-O5    57200
# 11    UCI4723_CX1718_LEC_1_P1-1-I3    55803
# 12    UCI4723_CX1718_LEC_1_P2-1-E5    54540
# 13   UCI4723_CX1718_LEC_1_P14-1-J3    54248
# 14   UCI4723_CX1718_LEC_1_P15-1-L3    52136
# 15  UCI4723_CX1718_LEC_1_P13-1-I24    49973
# 16                  Total Reads PF   932790
#       Pool  Total Reads
# 0  SALK102       634272
# 1  SALK103      1525380
# 2  SALK104      1414324
# 3  SALK105       932790

# %%
generate_read_adj_table(summary_df)
# Out:
#         Pool Combo     Pool  Total Reads  Read adj factor
# 0  SALK102_SALK105  SALK102       634272         1.470647
# 1  SALK102_SALK105  SALK105       932790         0.679973
# 2  SALK103_SALK104  SALK103      1525380         0.927195
# 3  SALK103_SALK104  SALK104      1414324         1.078522

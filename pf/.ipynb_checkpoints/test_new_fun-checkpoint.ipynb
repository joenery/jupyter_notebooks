# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart
import pandas as pd

# %%
#runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240626_M00412_0828_000000000-DNY32'
# List of tuples for run folders and pools
#run_folder_pool_pairs = get_pool_ids_from_directories(runs)
# Iterate over the list and call the function for each pair
#for run_folder, pool in run_folder_pool_pairs:
    #print(f'/gale/netapp/seq2/illumina_runs/{run_folder} {pool}')
    #generate_reads_pf_chart(run_folder, pool)

# %%
runs = '/gale/netapp/seq11/illumina_runs/bclconvert_scripts/240626_M00412_0828_000000000-DNY32'
# List of tuples for run folders and pools
run_folder_pool_pairs = get_pool_ids_from_directories(runs)

# Initialize a list to store total reads for each pool
pool_totals = []

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    full_run_folder_path = f'/gale/netapp/seq2/illumina_runs/{run_folder}'
    print(f'{full_run_folder_path} {pool}')
    total_reads = generate_reads_pf_chart(full_run_folder_path, pool)
    pool_totals.append((pool, total_reads))

# Create a summary DataFrame
summary_df = pd.DataFrame(pool_totals, columns=['Pool', 'Total Reads'])

# Print the summary table
print(summary_df)
# Out:
# /gale/netapp/seq2/illumina_runs/240626_M00412_0828_000000000-DNY32_240627090413312174861 SALK082
#                             SampleID  # Reads
# 0    UCI4723_CX1516_PalCx_1_P1-1-K15    55789
# 1    UCI4723_CX1516_PalCx_1_P15-1-H6    53575
# 2   UCI4723_CX1516_PalCx_1_P10-1-J11    53232
# 3    UCI4723_CX1516_PalCx_1_P13-1-D6    44349
# 4    UCI4723_CX1516_PalCx_1_P8-1-G10    43501
# 5    UCI4723_CX1516_PalCx_1_P2-1-M17    43132
# 6    UCI4723_CX1516_PalCx_1_P9-1-B11    39641
# 7    UCI4723_CX1516_PalCx_1_P4-1-O21    38081
# 8    UCI4723_CX1516_PalCx_1_P3-1-C21    37620
# 9    UCI4723_CX1516_PalCx_1_P11-1-J2    35260
# 10   UCI4723_CX1516_PalCx_1_P5-1-C23    33885
# 11   UCI4723_CX1516_PalCx_1_P7-1-C10    33527
# 12   UCI4723_CX1516_PalCx_1_P14-1-F6    32172
# 13    UCI4723_CX1516_PalCx_1_P6-1-I2    29133
# 14   UCI4723_CX1516_PalCx_1_P12-1-B6    27568
# 15   UCI4723_CX1516_PalCx_1_P16-1-D8     9832
# 16                    Total Reads PF   610297
# /gale/netapp/seq2/illumina_runs/240626_M00412_0828_000000000-DNY32_240627122301393085266 SALK084
#                        SampleID  # Reads
# 0    UCI4723_CX13_A8_1_P15-1-O4    27513
# 1    UCI4723_CX13_A8_1_P7-1-B19    26836
# 2    UCI4723_CX13_A8_1_P6-1-A22    26614
# 3    UCI4723_CX13_A8_1_P2-1-P13    26084
# 4    UCI4723_CX13_A8_1_P14-1-P6    25495
# 5     UCI4723_CX13_A8_1_P9-1-G9    24754
# 6   UCI4723_CX13_A8_1_P16-1-J18    24359
# 7   UCI4723_CX13_A8_1_P10-1-I17    24136
# 8   UCI4723_CX13_A8_1_P13-1-J24    24006
# 9     UCI4723_CX13_A8_1_P1-1-I5    23570
# 10    UCI4723_CX13_A8_1_P3-1-F3    23362
# 11    UCI4723_CX13_A8_1_P8-1-A7    23306
# 12   UCI4723_CX13_A8_1_P11-1-E9    23304
# 13    UCI4723_CX13_A8_1_P4-1-E6    21858
# 14   UCI4723_CX13_A8_1_P5-1-G17    21540
# 15   UCI4723_CX13_A8_1_P12-1-N8    20615
# 16               Total Reads PF   387352
#       Pool  Total Reads
# 0  SALK082       610297
# 1  SALK084       387352

# %%
summary_df.loc[summary_df['Pool'] == ['SALK082', 'SALK084'], 'Total Reads'].values[1]
# Out:
# 387352

# %%
# Calculate the quotients
quotient_1 = summary_df.loc[1, 'Total Reads'] / summary_df.loc[0, 'Total Reads']
quotient_2 = summary_df.loc[0, 'Total Reads'] / summary_df.loc[1, 'Total Reads']

# %%
tot_reads[] = [summary_df.loc[0, 'Total Reads'], summary_df.loc[1, 'Total Reads']]
# Out:
#   Input In [19]
#     tot_reads[summary_df.loc[summary_df.loc[0, 'Total Reads'], summary_df.loc[1, 'Total Reads'] ]
#                                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
from pf import get_pool_ids_from_directories, generate_reads_pf_chart

# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder = '/gale/netapp/seq11/illumina_runs/240522_LH00296_0030_A222VN2LT4/Analysis/1/Data/Demux'


# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
# /gale/netapp/seq2/illumina_runs/240515_M00412_0814_000000000-DMWTF_240516110451375645321 SALK062
#                             SampleID  # Reads
# 0     UWA7648_CX2324_SubTH_1_P5-1-K9    33630
# 1   UWA7648_CX2324_SubTH_1_P11-1-K20    32468
# 2     UWA7648_CX2324_SubTH_1_P3-1-O5    31617
# 3     UWA7648_CX2324_SubTH_1_P6-1-M9    31434
# 4    UWA7648_CX2324_SubTH_1_P7-1-A11    30866
# 5     UWA7648_CX2324_SubTH_1_P1-1-I3    30520
# 6    UWA7648_CX2324_SubTH_1_P8-1-I15    30505
# 7     UWA7648_CX2324_SubTH_1_P4-1-C7    30116
# 8     UWA7648_CX2324_SubTH_1_P2-1-E5    30059
# 9        UWA7648_BS02_MGM3_1_P5-1-J7    29847
# 10       UWA7648_BS02_MGM3_1_P3-1-J3    28949
# 11      UWA7648_BS02_MGM3_1_P2-1-I24    28496
# 12   UWA7648_CX2324_SubTH_1_P9-1-M14    28419
# 13  UWA7648_CX2324_SubTH_1_P10-1-K18    27700
# 14       UWA7648_BS02_MGM3_1_P4-1-L3    26967
# 15      UWA7648_BS02_MGM3_1_P1-1-E22    26925
# 16                    Total Reads PF   478518
# /gale/netapp/seq2/illumina_runs/240515_M00412_0814_000000000-DMWTF_240516110454302194700 SALK063
#                              SampleID  # Reads
# 0    UWA7648_BS030405_PnTg_1_P5-1-C23    51235
# 1    UWA7648_BS030405_PnTg_1_P3-1-C21    50973
# 2    UWA7648_BS030405_PnTg_1_P1-1-K15    50117
# 3    UWA7648_BS030405_PnTg_1_P8-1-G10    46216
# 4     UWA7648_BS030405_PnTg_1_P6-1-I2    43840
# 5    UWA7648_BS030405_PnTg_1_P4-1-O21    40957
# 6    UWA7648_BS030405_PnTg_1_P9-1-B11    38220
# 7    UWA7648_BS030405_PnTg_1_P13-1-D6    37204
# 8    UWA7648_BS030405_PnTg_1_P2-1-M17    36667
# 9   UWA7648_BS030405_PnTg_1_P10-1-J11    35375
# 10   UWA7648_BS030405_PnTg_1_P12-1-B6    35197
# 11   UWA7648_BS030405_PnTg_1_P14-1-F6    34455
# 12   UWA7648_BS030405_PnTg_1_P15-1-H6    32637
# 13   UWA7648_BS030405_PnTg_1_P11-1-J2    31947
# 14   UWA7648_BS030405_PnTg_1_P16-1-D8    30071
# 15   UWA7648_BS030405_PnTg_1_P7-1-C10        9
# 16                     Total Reads PF   595120

# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("240215_M00412_0785_000000000-GJMYH_240216105941024323705", "SALK037_PhiX"),
    ("240215_M00412_0785_000000000-GJMYH_240216103823818416955", "SALK037"),
    ("240215_M00412_0785_000000000-GJMYH_240216103825363775083", "SALK038"),
    ("240215_M00412_0785_000000000-GJMYH_240216103826356989343", "SALK039")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                             SampleID  # Reads
# 0        UWA7648_CX23_LEC_2_P11-1-E9   104492
# 1        UWA7648_CX23_LEC_2_P6-1-A22   103875
# 2       UWA7648_CX23_LEC_2_P10-1-I17   100492
# 3         UWA7648_CX23_LEC_2_P9-1-G9    95747
# 4    UWA7648_CX192021_CaB_1_P8-1-F12    93788
# 5    UWA7648_CX192021_CaB_1_P5-1-P21    92914
# 6     UWA7648_CX192021_CaB_1_P6-1-G5    91779
# 7   UWA7648_CX192021_CaB_2_P12-1-J24    85942
# 8    UWA7648_CX192021_CaB_2_P11-1-N8    85064
# 9         UWA7648_CX23_LEC_2_P4-1-E6    79948
# 10       UWA7648_CX23_LEC_2_P5-1-G17    78207
# 11       UWA7648_CX23_LEC_2_P7-1-B19    75791
# 12       UWA7648_CX23_LEC_2_P2-1-P13    74929
# 13        UWA7648_CX23_LEC_2_P3-1-F3    73907
# 14        UWA7648_CX23_LEC_2_P8-1-A7    70156
# 15        UWA7648_CX23_LEC_2_P1-1-I5    63093
# 16                              PhiX        0
# 17                    Total Reads PF  1370124
#                             SampleID  # Reads
# ...

# %%
from pf import generate_reads_pf_chart
# List of tuples for run folders and pools
run_folder_pool_pairs = [
    ("231114_M00412_0746_000000000-DM344_231114150945397462474", "Pool_AD3C_95_96"),
    ("231114_M00412_0746_000000000-DM344_231114155758071588830", "Pool_AD3C_97_98")
]

# Iterate over the list and call the function for each pair
for run_folder, pool in run_folder_pool_pairs:
    generate_reads_pf_chart(run_folder, pool)
# Out:
#                                              SampleID  # Reads
# 0   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    19399
# 1   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    17485
# 2   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    17318
# 3   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16350
# 4   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16273
# 5   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15951
# 6   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15845
# 7   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15814
# 8   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15513
# 9   231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15419
# 10  231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15336
# 11  231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15332
# 12  231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15043
# 13  231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    14970
# 14  231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    14638
# 15  231109-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    12974
# 16                                     Total Reads PF   253660
#                                              SampleID  # Reads
# 0   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    18239
# 1   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    17719
# 2   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16923
# 3   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16768
# 4   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16634
# 5   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16565
# 6   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16564
# 7   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    16220
# 8   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15838
# 9   231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15821
# 10  231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15749
# 11  231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15362
# 12  231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15200
# 13  231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    15001
# 14  231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    14577
# 15  231113-AD3C-hs-snm3C_seq-NovaSeq-pe-150-PB-AD3...    14068
# 16                                     Total Reads PF   257248
